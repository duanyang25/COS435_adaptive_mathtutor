# %%
import ollama
from ollama import chat
from ollama import ChatResponse

import pandas as pd
import numpy as np

import json
import re
import requests
import time

# %%
# # response: ChatResponse = chat(model='qwq:32b', messages=[
# #   {
# #     'role': 'user',
# #     'content': 'Why is the sky blue?',
# #   },
# # ])
# # print(response['message']['content'])

# from ollama import Client
# client = Client(
#   host='http://localhost:11434',
#   headers = {
#         "Content-Type": "application/json"
#     }
# )

# %%
df = pd.read_pickle("./dataset/processed.pkl")  
df

columns = [
    'question',
    'ground_truth',
    'student_incorrect_solution',
    'student_profile',
    'conversation',
    'state',
    'action_text',
    'done'
]

new_df = df[columns]

state_df = new_df.copy()
state_df['full_state'] = None

for i in range(0, len(new_df)):
  if 'START' in str(new_df.iloc[i]['state']):
    state_df.at[i, 'full_state'] = ['', 'START']
    continue

  prev_action_text = new_df.iloc[i-1]['action_text']
  curr_state = new_df.iloc[i]['state']

  state_df.at[i, 'full_state'] = [prev_action_text, curr_state]

state_df

state_df['conversation']
curr_pos = 1
if len(state_df) > 0:
  state_df.loc[0, 'convo_turn'] = curr_pos

for i in range(1, len(state_df)):
    # Check if a new conversation starts (0 follows a 1)
    if state_df.loc[i-1, 'done'] == 1 and state_df.loc[i, 'done'] == 0:
        # Reset position counter for new conversation
        curr_pos = 1
    else:
        # Increment position within the same conversation
        curr_pos += 1

    # Assign the current position within conversation
    state_df.loc[i, 'convo_turn'] = curr_pos * 1

state_df['convo_turn'] = state_df['convo_turn'].astype(int)
state_df['old_state'] = state_df['state']
state_df['state'] = state_df['full_state']
state_df
# Out:
#                                                 question  \
# 0      Nancy is filling an aquarium for her fish. She...
# 1      Nancy is filling an aquarium for her fish. She...
# 2      Nancy is filling an aquarium for her fish. She...
# 3      John is very unfit and decides to work up to d...
# 4      John is very unfit and decides to work up to d...
# ...                                                  ...
# 20149  Andy is checking to see if all the cars in the...
# 20150  Andy is checking to see if all the cars in the...
# 20151  Andy is checking to see if all the cars in the...
# 20152  Andy is checking to see if all the cars in the...
# 20153  Andy is checking to see if all the cars in the...
#
#                                             ground_truth  \
# 0      First calculate the volume of the aquarium by ...
# 1      First calculate the volume of the aquarium by ...
# 2      First calculate the volume of the aquarium by ...
# 3      He needs to do 15*3=45 progressions\nThat will...
# 4      He needs to do 15*3=45 progressions\nThat will...
# ...                                                  ...
# 20149  First find how many cars have valid tickets: 7...
# 20150  First find how many cars have valid tickets: 7...
# 20151  First find how many cars have valid tickets: 7...
# 20152  First find how many cars have valid tickets: 7...
# 20153  First find how many cars have valid tickets: 7...
#
#                               student_incorrect_solution  \
# 0      The aquarium has a volume of 4 x 6 x 3 = 72 cu...
# 1      The aquarium has a volume of 4 x 6 x 3 = 72 cu...
# 2      The aquarium has a volume of 4 x 6 x 3 = 72 cu...
# 3      To get to 15 reps, John will take 15 - 1 = 14 ...
# 4      To get to 15 reps, John will take 15 - 1 = 14 ...
# ...                                                  ...
# 20149  75% of the cars have valid tickets, so 100%-75...
# 20150  75% of the cars have valid tickets, so 100%-75...
# 20151  75% of the cars have valid tickets, so 100%-75...
# 20152  75% of the cars have valid tickets, so 100%-75...
# 20153  75% of the cars have valid tickets, so 100%-75...
#
#                                          student_profile  \
# 0      Steven is a 7th grade student. He has difficul...
# 1      Steven is a 7th grade student. He has difficul...
# 2      Steven is a 7th grade student. He has difficul...
# 3      Stephanie is a 7th grade student. She has diff...
# 4      Stephanie is a 7th grade student. She has diff...
# ...                                                  ...
# 20149  Stephanie is a 7th grade student. She struggle...
# 20150  Stephanie is a 7th grade student. She struggle...
# 20151  Stephanie is a 7th grade student. She struggle...
# 20152  Stephanie is a 7th grade student. She struggle...
# 20153  Stephanie is a 7th grade student. She struggle...
#
#                                             conversation  \
# 0      Teacher: (probing)Steven, If you had 4 of some...
# 1      Teacher: (probing)Steven, If you had 4 of some...
# 2      Teacher: (probing)Steven, If you had 4 of some...
# 3      Teacher: (probing)Stephanie, How many days wil...
# 4      Teacher: (probing)Stephanie, How many days wil...
# ...                                                  ...
# 20149  Teacher: (generic)Hi, could you please walk me...
# 20150  Teacher: (generic)Hi, could you please walk me...
# 20151  Teacher: (generic)Hi, could you please walk me...
# 20152  Teacher: (generic)Hi, could you please walk me...
# 20153  Teacher: (generic)Hi, could you please walk me...
#
#                                                    state  \
# 0                                              [, START]
# 1      [Teacher: (probing)Steven, If you had 4 of som...
# 2      [Teacher: (probing)So if Nancy triples the 18 ...
# 3                                              [, START]
# 4      [Teacher: (probing)Stephanie, How many days wi...
# ...                                                  ...
# 20149  [Teacher: (generic)Hi, could you please walk m...
# 20150  [Teacher: (focus)That doesn't seem to be corre...
# 20151  [Teacher: (focus)Great. The question now says ...
# 20152  [Teacher: (focus)That's wonderful. So now what...
# 20153  [Teacher: (generic)There's your answer. I hope...
#
#                                              action_text  done  \
# 0      Teacher: (probing)Steven, If you had 4 of some...     0
# 1      Teacher: (probing)So if Nancy triples the 18 c...     0
# 2                     Teacher: (generic)Exactly correct!     1
# 3      Teacher: (probing)Stephanie, How many days wil...     0
# 4      Teacher: (probing)So how many days will it tak...     0
# ...                                                  ...   ...
# 20149  Teacher: (focus)That doesn't seem to be correc...     0
# 20150  Teacher: (focus)Great. The question now says t...     0
# 20151  Teacher: (focus)That's wonderful. So now what ...     0
# 20152  Teacher: (generic)There's your answer. I hope ...     0
# 20153                                                NaN     1
#
#                                               full_state  convo_turn  \
# 0                                              [, START]           1
# 1      [Teacher: (probing)Steven, If you had 4 of som...           2
# 2      [Teacher: (probing)So if Nancy triples the 18 ...           3
# 3                                              [, START]           1
# 4      [Teacher: (probing)Stephanie, How many days wi...           2
# ...                                                  ...         ...
# 20149  [Teacher: (generic)Hi, could you please walk m...           2
# 20150  [Teacher: (focus)That doesn't seem to be corre...           3
# 20151  [Teacher: (focus)Great. The question now says ...           4
# 20152  [Teacher: (focus)That's wonderful. So now what...           5
# 20153  [Teacher: (generic)There's your answer. I hope...           6
#
#                                                old_state
# 0                                                  START
# 1                  Steven: I would have 12 of something.
# 2         Steven: She would have 54 cubic feet of water.
# 3                                                  START
# 4      Student: It will take one day to do one step, ...
# ...                                                  ...
# 20149  Student: Sure, I said that 75% of the cars hav...
# 20150  Student: Sure. I said that 75% of the cars hav...
# 20151  Student: Yes, 1/5th of 225 cars is (1/5)*225 =...
# 20152  Student: There are 225 cars with valid tickets...
# 20153      Student: Yes, I got it. Thanks for your help!
#
# [20154 rows x 11 columns]

# %% [markdown]
# # Prompt

# %%
# for i, row in state_df.iterrows():
#     if i == 5:
#         break
#     # Gather your fields
#     question = row.get("question", "")
#     correct_solution = row.get("ground_truth", "")
#     student_profile = row.get("student_profile", "")
#     current_conversation_state = row.get("state", "")
#     conversation_turn = row.get("convo_turn", "")
#     action_text = row.get("action_text", "")
#     prompt = f"""
# You are analyzing math tutoring sessions to extract features for an AI tutor.

# CONTEXT:
# - Question: {question}
# - Correct solution: {correct_solution}
# - Student profile: {student_profile}
# - Current conversation: {current_conversation_state}
# - Conversation turn: {conversation_turn}
# - Next action text: {action_text}

# TASK:
# Extract the following features from this tutoring interaction:

# 1. MISCONCEPTION TYPE - This classification MUST be determined SOLELY from the student profile, not from the conversation. It represents the student's core misunderstanding and should be CONSISTENT across all interactions with this same student. Choose ONE of these types based only on the student profile description:
# - operation_error: Student applies the wrong operation (e.g., adding instead of multiplying)
# - number_fact_error: Student makes errors in basic number facts (e.g., multiplication tables)
# - variable_meaning_error: Student misunderstands what variables represent
# - conceptual_error: Student has fundamental misconception about a math concept
# - calculation_error: Student makes arithmetic errors during calculation
# - problem_interpretation_error: Student misunderstands what the problem is asking

# 2. LISTEN TO FEEDBACK:
#    - 1 if the student has incorporated the teacher's feedback in the current conversation state
#    - 0 if not

# 3. PROBLEM PROGRESS - Numerical estimate (0-100) of how close, given the student's current conversation state, the student is to the correct solution. For example:
#   - 0: No progress/completely wrong approach
#   - 25: Beginning to understand but major errors remain
#   - 50: Halfway to solution with some key insights
#   - 75: Minor errors but mostly correct approach
#   - 100: Complete and correct solution
#   (You may use any value between 0-100, not just the examples above)

# 4. PROBLEM CONCEPT:
#    The specific math domain/concept being tested. Based on the question, choose the one most relevant concept: "basic_arithmetic", "fractions_decimals_and_percents", "ratios_proportions_and_rates", "measurement_and_geometry", "counting_and_combinatorics", "money_and_finance", or "algebraic_relationships".

# 5. CONVERSATION TURN:
#    The number of exchanges so far.

# 6. CORRECT SOLUTION:
#    - 0 if the student's final answer is incorrect
#    - 1 if correct

# 7. PROBLEM DIFFICULTY (1-3):
#    Rate how difficult the math question is on a scale from 1 to 5, where:
#    - 1 = Very easy, basic concepts, straightforward approach
#    - 2 = Moderate, requires some thought, multiple steps
#    - 3 = Challenging, complex approach, requires deeper understanding

# 8. NEXT ACTION HINT STRENGTH (0-4):
#    How strong is the teacher's hint? (0=very minimal hint, 4=essentially giving away the entire solution)

# 9. NEXT ACTION CATEGORY:
#    - Focus
#    - Probing
#    - Telling
#    - Generic

# 10. NEXT ACTION SUBCATEGORY:
#     Choose **exactly one** of the following, depending on the category:

#     **Focus**:
#     - "Seek Next Step"
#     - "Confirm Calculation"
#     - "Re-direct to Sub-Problem"
#     - "Highlight Missing Info"

#     **Probing**:
#     - "Ask for Explanation"
#     - "Seek Self-Correction"
#     - "Hypothetical Variation"
#     - "Check Understanding/Concept"
#     - "Encourage Comparison"

#     **Telling**:
#     - "Partial Reveal (Strategy)"
#     - "Full Reveal (Answer)"
#     - "Corrective Explanation"

#     **Generic**:
#     - "Greeting/Farewell"
#     - "Acknowledgment/Praise"
#     - "Summarize Progress"
#     - "General Inquiry/Filler"

# FORMAT YOUR RESPONSE AS JSON:
# {{
#   "state": {{
#     "misconception_type": "one_of_the_six_types",
#     "listen_to_feedback": 0 or 1,
#     "problem_progress": integer_between_0_and_100,
#     "problem_concept": "specific_math_concept",
#     "conversation_turn": integer,
#     "correct_solution": 0 or 1,
#     "problem_difficulty": integer_between_1_and_3
#   }},
#   "action": {{
#     "next_action_hint_strength": integer_between_0_and_4,
#     "next_action_category": "Focus/Probing/Telling/Generic",
#     "next_action_subcategory": "pick_the_exact_one_subcategory_name"
#   }}
# }}

# IMPORTANT:
# - Return ONLY the JSON object with no additional explanation
# - All numeric fields must be valid integers
# """
#     print(i, prompt)
# Out:
# 0
# You are analyzing math tutoring sessions to extract features for an AI tutor.
#
# CONTEXT:
# - Question: Nancy is filling an aquarium for her fish. She fills it halfway and goes to answer the door. While she's gone, her cat knocks the aquarium over and spills half the water in it. Then Nancy comes back and triples the amount of water in the aquarium. If the aquarium is 4 feet long, 6 feet wide, and 3 feet high, how many cubic feet of water are in the aquarium?
# - Correct solution: First calculate the volume of the aquarium by multiplying its length, width and height: 4 ft * 6 ft * 3 ft = 72 cubic ft
# Then figure out what proportion of the aquarium is full after the cat knocks it over: 1/2 * 1/2 = 1/4
# Then figure out what proportion of the aquarium is full after Nancy refills it: 3 * 1/4 = 3/4
# Now multiply the proportion of the aquarium that's full by the aquarium's volume to find out how much water is in it: 72 cubic ft * 3/4 = 54 cubic ft
#  54
# - Student profile: Steven is a 7th grade student. He has difficulty determining which pieces of information are relevant and which are irrelevant to solving the problem.
# - Current conversation: ['', 'START']
# - Conversation turn: 1
# - Next action text: Teacher: (probing)Steven, If you had 4 of something and tripled that amount, how much would you have?
#
# TASK:
# Extract the following features from this tutoring interaction:
#
# 1. MISCONCEPTION TYPE - This classification MUST be determined SOLELY from the student profile, not from the conversation. It represents the student's core misunderstanding and should be CONSISTENT across all interactions with this same student. Choose ONE of these types based only on the student profile description:
# - operation_error: Student applies the wrong operation (e.g., adding instead of multiplying)
# - number_fact_error: Student makes errors in basic number facts (e.g., multiplication tables)
# - variable_meaning_error: Student misunderstands what variables represent
# - conceptual_error: Student has fundamental misconception about a math concept
# - calculation_error: Student makes arithmetic errors during calculation
# - problem_interpretation_error: Student misunderstands what the problem is asking
#
# 2. LISTEN TO FEEDBACK:
#    - 1 if the student has incorporated the teacher's feedback in the current conversation state
#    - 0 if not
#
# 3. PROBLEM PROGRESS - Numerical estimate (0-100) of how close, given the student's current conversation state, the student is to the correct solution. For example:
#   - 0: No progress/completely wrong approach
#   - 25: Beginning to understand but major errors remain
#   - 50: Halfway to solution with some key insights
#   - 75: Minor errors but mostly correct approach
#   - 100: Complete and correct solution
#   (You may use any value between 0-100, not just the examples above)
#
# 4. PROBLEM CONCEPT:
#    The specific math domain/concept being tested. Based on the question, choose the one most relevant concept: "basic_arithmetic", "fractions_decimals_and_percents", "ratios_proportions_and_rates", "measurement_and_geometry", "counting_and_combinatorics", "money_and_finance", or "algebraic_relationships".
#
# 5. CONVERSATION TURN:
#    The number of exchanges so far.
#
# 6. CORRECT SOLUTION:
#    - 0 if the student's final answer is incorrect
#    - 1 if correct
#
# 7. PROBLEM DIFFICULTY (1-3):
#    Rate how difficult the math question is on a scale from 1 to 5, where:
#    - 1 = Very easy, basic concepts, straightforward approach
#    - 2 = Moderate, requires some thought, multiple steps
#    - 3 = Challenging, complex approach, requires deeper understanding
#
# 8. NEXT ACTION HINT STRENGTH (0-4):
#    How strong is the teacher's hint? (0=very minimal hint, 4=essentially giving away the entire solution)
#
# 9. NEXT ACTION CATEGORY:
#    - Focus
#    - Probing
#    - Telling
#    - Generic
#
# 10. NEXT ACTION SUBCATEGORY:
#     Choose **exactly one** of the following, depending on the category:
#
#     **Focus**:
#     - "Seek Next Step"
#     - "Confirm Calculation"
#     - "Re-direct to Sub-Problem"
#     - "Highlight Missing Info"
#
#     **Probing**:
#     - "Ask for Explanation"
#     - "Seek Self-Correction"
#     - "Hypothetical Variation"
#     - "Check Understanding/Concept"
#     - "Encourage Comparison"
#
#     **Telling**:
#     - "Partial Reveal (Strategy)"
#     - "Full Reveal (Answer)"
#     - "Corrective Explanation"
#
#     **Generic**:
#     - "Greeting/Farewell"
#     - "Acknowledgment/Praise"
#     - "Summarize Progress"
#     - "General Inquiry/Filler"
#
# FORMAT YOUR RESPONSE AS JSON:
# {
#   "state": {
#     "misconception_type": "one_of_the_six_types",
#     "listen_to_feedback": 0 or 1,
#     "problem_progress": integer_between_0_and_100,
#     "problem_concept": "specific_math_concept",
#     "conversation_turn": integer,
#     "correct_solution": 0 or 1,
#     "problem_difficulty": integer_between_1_and_3
#   },
#   "action": {
#     "next_action_hint_strength": integer_between_0_and_4,
#     "next_action_category": "Focus/Probing/Telling/Generic",
#     "next_action_subcategory": "pick_the_exact_one_subcategory_name"
#   }
# }
#
# IMPORTANT:
# - Return ONLY the JSON object with no additional explanation
# - All numeric fields must be valid integers
#
# 1
# You are analyzing math tutoring sessions to extract features for an AI tutor.
#
# CONTEXT:
# - Question: Nancy is filling an aquarium for her fish. She fills it halfway and goes to answer the door. While she's gone, her cat knocks the aquarium over and spills half the water in it. Then Nancy comes back and triples the amount of water in the aquarium. If the aquarium is 4 feet long, 6 feet wide, and 3 feet high, how many cubic feet of water are in the aquarium?
# - Correct solution: First calculate the volume of the aquarium by multiplying its length, width and height: 4 ft * 6 ft * 3 ft = 72 cubic ft
# Then figure out what proportion of the aquarium is full after the cat knocks it over: 1/2 * 1/2 = 1/4
# Then figure out what proportion of the aquarium is full after Nancy refills it: 3 * 1/4 = 3/4
# Now multiply the proportion of the aquarium that's full by the aquarium's volume to find out how much water is in it: 72 cubic ft * 3/4 = 54 cubic ft
#  54
# - Student profile: Steven is a 7th grade student. He has difficulty determining which pieces of information are relevant and which are irrelevant to solving the problem.
# - Current conversation: ['Teacher: (probing)Steven, If you had 4 of something and tripled that amount, how much would you have?', 'Steven: I would have 12 of something.']
# - Conversation turn: 2
# - Next action text: Teacher: (probing)So if Nancy triples the 18 cubic feet of water, how much would she have?
#
# TASK:
# Extract the following features from this tutoring interaction:
#
# 1. MISCONCEPTION TYPE - This classification MUST be determined SOLELY from the student profile, not from the conversation. It represents the student's core misunderstanding and should be CONSISTENT across all interactions with this same student. Choose ONE of these types based only on the student profile description:
# - operation_error: Student applies the wrong operation (e.g., adding instead of multiplying)
# - number_fact_error: Student makes errors in basic number facts (e.g., multiplication tables)
# - variable_meaning_error: Student misunderstands what variables represent
# - conceptual_error: Student has fundamental misconception about a math concept
# - calculation_error: Student makes arithmetic errors during calculation
# - problem_interpretation_error: Student misunderstands what the problem is asking
#
# 2. LISTEN TO FEEDBACK:
#    - 1 if the student has incorporated the teacher's feedback in the current conversation state
#    - 0 if not
#
# 3. PROBLEM PROGRESS - Numerical estimate (0-100) of how close, given the student's current conversation state, the student is to the correct solution. For example:
#   - 0: No progress/completely wrong approach
#   - 25: Beginning to understand but major errors remain
#   - 50: Halfway to solution with some key insights
#   - 75: Minor errors but mostly correct approach
#   - 100: Complete and correct solution
#   (You may use any value between 0-100, not just the examples above)
#
# 4. PROBLEM CONCEPT:
#    The specific math domain/concept being tested. Based on the question, choose the one most relevant concept: "basic_arithmetic", "fractions_decimals_and_percents", "ratios_proportions_and_rates", "measurement_and_geometry", "counting_and_combinatorics", "money_and_finance", or "algebraic_relationships".
#
# 5. CONVERSATION TURN:
#    The number of exchanges so far.
#
# 6. CORRECT SOLUTION:
#    - 0 if the student's final answer is incorrect
#    - 1 if correct
#
# 7. PROBLEM DIFFICULTY (1-3):
#    Rate how difficult the math question is on a scale from 1 to 5, where:
#    - 1 = Very easy, basic concepts, straightforward approach
#    - 2 = Moderate, requires some thought, multiple steps
#    - 3 = Challenging, complex approach, requires deeper understanding
#
# 8. NEXT ACTION HINT STRENGTH (0-4):
#    How strong is the teacher's hint? (0=very minimal hint, 4=essentially giving away the entire solution)
#
# 9. NEXT ACTION CATEGORY:
#    - Focus
#    - Probing
#    - Telling
#    - Generic
#
# 10. NEXT ACTION SUBCATEGORY:
#     Choose **exactly one** of the following, depending on the category:
#
#     **Focus**:
#     - "Seek Next Step"
#     - "Confirm Calculation"
#     - "Re-direct to Sub-Problem"
#     - "Highlight Missing Info"
#
#     **Probing**:
#     - "Ask for Explanation"
#     - "Seek Self-Correction"
#     - "Hypothetical Variation"
#     - "Check Understanding/Concept"
#     - "Encourage Comparison"
#
#     **Telling**:
#     - "Partial Reveal (Strategy)"
#     - "Full Reveal (Answer)"
#     - "Corrective Explanation"
#
#     **Generic**:
#     - "Greeting/Farewell"
#     - "Acknowledgment/Praise"
#     - "Summarize Progress"
#     - "General Inquiry/Filler"
#
# FORMAT YOUR RESPONSE AS JSON:
# {
#   "state": {
#     "misconception_type": "one_of_the_six_types",
#     "listen_to_feedback": 0 or 1,
#     "problem_progress": integer_between_0_and_100,
#     "problem_concept": "specific_math_concept",
#     "conversation_turn": integer,
#     "correct_solution": 0 or 1,
#     "problem_difficulty": integer_between_1_and_3
#   },
#   "action": {
#     "next_action_hint_strength": integer_between_0_and_4,
#     "next_action_category": "Focus/Probing/Telling/Generic",
#     "next_action_subcategory": "pick_the_exact_one_subcategory_name"
#   }
# }
#
# IMPORTANT:
# - Return ONLY the JSON object with no additional explanation
# - All numeric fields must be valid integers
#
# 2
# You are analyzing math tutoring sessions to extract features for an AI tutor.
#
# CONTEXT:
# - Question: Nancy is filling an aquarium for her fish. She fills it halfway and goes to answer the door. While she's gone, her cat knocks the aquarium over and spills half the water in it. Then Nancy comes back and triples the amount of water in the aquarium. If the aquarium is 4 feet long, 6 feet wide, and 3 feet high, how many cubic feet of water are in the aquarium?
# - Correct solution: First calculate the volume of the aquarium by multiplying its length, width and height: 4 ft * 6 ft * 3 ft = 72 cubic ft
# Then figure out what proportion of the aquarium is full after the cat knocks it over: 1/2 * 1/2 = 1/4
# Then figure out what proportion of the aquarium is full after Nancy refills it: 3 * 1/4 = 3/4
# Now multiply the proportion of the aquarium that's full by the aquarium's volume to find out how much water is in it: 72 cubic ft * 3/4 = 54 cubic ft
#  54
# - Student profile: Steven is a 7th grade student. He has difficulty determining which pieces of information are relevant and which are irrelevant to solving the problem.
# - Current conversation: ['Teacher: (probing)So if Nancy triples the 18 cubic feet of water, how much would she have?', 'Steven: She would have 54 cubic feet of water.']
# - Conversation turn: 3
# - Next action text: Teacher: (generic)Exactly correct!
#
# TASK:
# Extract the following features from this tutoring interaction:
#
# 1. MISCONCEPTION TYPE - This classification MUST be determined SOLELY from the student profile, not from the conversation. It represents the student's core misunderstanding and should be CONSISTENT across all interactions with this same student. Choose ONE of these types based only on the student profile description:
# - operation_error: Student applies the wrong operation (e.g., adding instead of multiplying)
# - number_fact_error: Student makes errors in basic number facts (e.g., multiplication tables)
# - variable_meaning_error: Student misunderstands what variables represent
# - conceptual_error: Student has fundamental misconception about a math concept
# - calculation_error: Student makes arithmetic errors during calculation
# - problem_interpretation_error: Student misunderstands what the problem is asking
#
# 2. LISTEN TO FEEDBACK:
#    - 1 if the student has incorporated the teacher's feedback in the current conversation state
#    - 0 if not
#
# 3. PROBLEM PROGRESS - Numerical estimate (0-100) of how close, given the student's current conversation state, the student is to the correct solution. For example:
#   - 0: No progress/completely wrong approach
#   - 25: Beginning to understand but major errors remain
#   - 50: Halfway to solution with some key insights
#   - 75: Minor errors but mostly correct approach
#   - 100: Complete and correct solution
#   (You may use any value between 0-100, not just the examples above)
#
# 4. PROBLEM CONCEPT:
#    The specific math domain/concept being tested. Based on the question, choose the one most relevant concept: "basic_arithmetic", "fractions_decimals_and_percents", "ratios_proportions_and_rates", "measurement_and_geometry", "counting_and_combinatorics", "money_and_finance", or "algebraic_relationships".
#
# 5. CONVERSATION TURN:
#    The number of exchanges so far.
#
# 6. CORRECT SOLUTION:
#    - 0 if the student's final answer is incorrect
#    - 1 if correct
#
# 7. PROBLEM DIFFICULTY (1-3):
#    Rate how difficult the math question is on a scale from 1 to 5, where:
#    - 1 = Very easy, basic concepts, straightforward approach
#    - 2 = Moderate, requires some thought, multiple steps
#    - 3 = Challenging, complex approach, requires deeper understanding
#
# 8. NEXT ACTION HINT STRENGTH (0-4):
#    How strong is the teacher's hint? (0=very minimal hint, 4=essentially giving away the entire solution)
#
# 9. NEXT ACTION CATEGORY:
#    - Focus
#    - Probing
#    - Telling
#    - Generic
#
# 10. NEXT ACTION SUBCATEGORY:
#     Choose **exactly one** of the following, depending on the category:
#
#     **Focus**:
#     - "Seek Next Step"
#     - "Confirm Calculation"
#     - "Re-direct to Sub-Problem"
#     - "Highlight Missing Info"
#
#     **Probing**:
#     - "Ask for Explanation"
#     - "Seek Self-Correction"
#     - "Hypothetical Variation"
#     - "Check Understanding/Concept"
#     - "Encourage Comparison"
#
#     **Telling**:
#     - "Partial Reveal (Strategy)"
#     - "Full Reveal (Answer)"
#     - "Corrective Explanation"
#
#     **Generic**:
#     - "Greeting/Farewell"
#     - "Acknowledgment/Praise"
#     - "Summarize Progress"
#     - "General Inquiry/Filler"
#
# FORMAT YOUR RESPONSE AS JSON:
# {
#   "state": {
#     "misconception_type": "one_of_the_six_types",
#     "listen_to_feedback": 0 or 1,
#     "problem_progress": integer_between_0_and_100,
#     "problem_concept": "specific_math_concept",
#     "conversation_turn": integer,
#     "correct_solution": 0 or 1,
#     "problem_difficulty": integer_between_1_and_3
#   },
#   "action": {
#     "next_action_hint_strength": integer_between_0_and_4,
#     "next_action_category": "Focus/Probing/Telling/Generic",
#     "next_action_subcategory": "pick_the_exact_one_subcategory_name"
#   }
# }
#
# IMPORTANT:
# - Return ONLY the JSON object with no additional explanation
# - All numeric fields must be valid integers
#
# 3
# You are analyzing math tutoring sessions to extract features for an AI tutor.
#
# CONTEXT:
# - Question: John is very unfit and decides to work up to doing a push-up.  He trains 5 days a week for them and starts with wall push-ups.  He adds 1 rep a day and once he gets to 15 reps he will start training high elevation push-ups. and then low elevation push-ups, and finally floor push-ups.  How many weeks will it take him to get to floor push-ups?
# - Correct solution: He needs to do 15*3=45 progressions
# That will take 45/5=9 weeks
#  9
# - Student profile: Stephanie is a 7th grade student. She has difficulty determining which pieces of information are relevant and which are irrelevant to solving the problem.
# - Current conversation: ['', 'START']
# - Conversation turn: 1
# - Next action text: Teacher: (probing)Stephanie, How many days will it take to do one step, if John adds one pushup per day?
#
# TASK:
# Extract the following features from this tutoring interaction:
#
# 1. MISCONCEPTION TYPE - This classification MUST be determined SOLELY from the student profile, not from the conversation. It represents the student's core misunderstanding and should be CONSISTENT across all interactions with this same student. Choose ONE of these types based only on the student profile description:
# - operation_error: Student applies the wrong operation (e.g., adding instead of multiplying)
# - number_fact_error: Student makes errors in basic number facts (e.g., multiplication tables)
# - variable_meaning_error: Student misunderstands what variables represent
# - conceptual_error: Student has fundamental misconception about a math concept
# - calculation_error: Student makes arithmetic errors during calculation
# - problem_interpretation_error: Student misunderstands what the problem is asking
#
# 2. LISTEN TO FEEDBACK:
#    - 1 if the student has incorporated the teacher's feedback in the current conversation state
#    - 0 if not
#
# 3. PROBLEM PROGRESS - Numerical estimate (0-100) of how close, given the student's current conversation state, the student is to the correct solution. For example:
#   - 0: No progress/completely wrong approach
#   - 25: Beginning to understand but major errors remain
#   - 50: Halfway to solution with some key insights
#   - 75: Minor errors but mostly correct approach
#   - 100: Complete and correct solution
#   (You may use any value between 0-100, not just the examples above)
#
# 4. PROBLEM CONCEPT:
#    The specific math domain/concept being tested. Based on the question, choose the one most relevant concept: "basic_arithmetic", "fractions_decimals_and_percents", "ratios_proportions_and_rates", "measurement_and_geometry", "counting_and_combinatorics", "money_and_finance", or "algebraic_relationships".
#
# 5. CONVERSATION TURN:
#    The number of exchanges so far.
#
# 6. CORRECT SOLUTION:
#    - 0 if the student's final answer is incorrect
#    - 1 if correct
#
# 7. PROBLEM DIFFICULTY (1-3):
#    Rate how difficult the math question is on a scale from 1 to 5, where:
#    - 1 = Very easy, basic concepts, straightforward approach
#    - 2 = Moderate, requires some thought, multiple steps
#    - 3 = Challenging, complex approach, requires deeper understanding
#
# 8. NEXT ACTION HINT STRENGTH (0-4):
#    How strong is the teacher's hint? (0=very minimal hint, 4=essentially giving away the entire solution)
#
# 9. NEXT ACTION CATEGORY:
#    - Focus
#    - Probing
#    - Telling
#    - Generic
#
# 10. NEXT ACTION SUBCATEGORY:
#     Choose **exactly one** of the following, depending on the category:
#
#     **Focus**:
#     - "Seek Next Step"
#     - "Confirm Calculation"
#     - "Re-direct to Sub-Problem"
#     - "Highlight Missing Info"
#
#     **Probing**:
#     - "Ask for Explanation"
#     - "Seek Self-Correction"
#     - "Hypothetical Variation"
#     - "Check Understanding/Concept"
#     - "Encourage Comparison"
#
#     **Telling**:
#     - "Partial Reveal (Strategy)"
#     - "Full Reveal (Answer)"
#     - "Corrective Explanation"
#
#     **Generic**:
#     - "Greeting/Farewell"
#     - "Acknowledgment/Praise"
#     - "Summarize Progress"
#     - "General Inquiry/Filler"
#
# FORMAT YOUR RESPONSE AS JSON:
# {
#   "state": {
#     "misconception_type": "one_of_the_six_types",
#     "listen_to_feedback": 0 or 1,
#     "problem_progress": integer_between_0_and_100,
#     "problem_concept": "specific_math_concept",
#     "conversation_turn": integer,
#     "correct_solution": 0 or 1,
#     "problem_difficulty": integer_between_1_and_3
#   },
#   "action": {
#     "next_action_hint_strength": integer_between_0_and_4,
#     "next_action_category": "Focus/Probing/Telling/Generic",
#     "next_action_subcategory": "pick_the_exact_one_subcategory_name"
#   }
# }
#
# IMPORTANT:
# - Return ONLY the JSON object with no additional explanation
# - All numeric fields must be valid integers
#
# 4
# You are analyzing math tutoring sessions to extract features for an AI tutor.
#
# CONTEXT:
# - Question: John is very unfit and decides to work up to doing a push-up.  He trains 5 days a week for them and starts with wall push-ups.  He adds 1 rep a day and once he gets to 15 reps he will start training high elevation push-ups. and then low elevation push-ups, and finally floor push-ups.  How many weeks will it take him to get to floor push-ups?
# - Correct solution: He needs to do 15*3=45 progressions
# That will take 45/5=9 weeks
#  9
# - Student profile: Stephanie is a 7th grade student. She has difficulty determining which pieces of information are relevant and which are irrelevant to solving the problem.
# - Current conversation: ['Teacher: (probing)Stephanie, How many days will it take to do one step, if John adds one pushup per day?', 'Student: It will take one day to do one step, since John adds one pushup per day.']
# - Conversation turn: 2
# - Next action text: Teacher: (probing)So how many days will it take to do 15 wall push-ups?
#
# TASK:
# Extract the following features from this tutoring interaction:
#
# 1. MISCONCEPTION TYPE - This classification MUST be determined SOLELY from the student profile, not from the conversation. It represents the student's core misunderstanding and should be CONSISTENT across all interactions with this same student. Choose ONE of these types based only on the student profile description:
# - operation_error: Student applies the wrong operation (e.g., adding instead of multiplying)
# - number_fact_error: Student makes errors in basic number facts (e.g., multiplication tables)
# - variable_meaning_error: Student misunderstands what variables represent
# - conceptual_error: Student has fundamental misconception about a math concept
# - calculation_error: Student makes arithmetic errors during calculation
# - problem_interpretation_error: Student misunderstands what the problem is asking
#
# 2. LISTEN TO FEEDBACK:
#    - 1 if the student has incorporated the teacher's feedback in the current conversation state
#    - 0 if not
#
# 3. PROBLEM PROGRESS - Numerical estimate (0-100) of how close, given the student's current conversation state, the student is to the correct solution. For example:
#   - 0: No progress/completely wrong approach
#   - 25: Beginning to understand but major errors remain
#   - 50: Halfway to solution with some key insights
#   - 75: Minor errors but mostly correct approach
#   - 100: Complete and correct solution
#   (You may use any value between 0-100, not just the examples above)
#
# 4. PROBLEM CONCEPT:
#    The specific math domain/concept being tested. Based on the question, choose the one most relevant concept: "basic_arithmetic", "fractions_decimals_and_percents", "ratios_proportions_and_rates", "measurement_and_geometry", "counting_and_combinatorics", "money_and_finance", or "algebraic_relationships".
#
# 5. CONVERSATION TURN:
#    The number of exchanges so far.
#
# 6. CORRECT SOLUTION:
#    - 0 if the student's final answer is incorrect
#    - 1 if correct
#
# 7. PROBLEM DIFFICULTY (1-3):
#    Rate how difficult the math question is on a scale from 1 to 5, where:
#    - 1 = Very easy, basic concepts, straightforward approach
#    - 2 = Moderate, requires some thought, multiple steps
#    - 3 = Challenging, complex approach, requires deeper understanding
#
# 8. NEXT ACTION HINT STRENGTH (0-4):
#    How strong is the teacher's hint? (0=very minimal hint, 4=essentially giving away the entire solution)
#
# 9. NEXT ACTION CATEGORY:
#    - Focus
#    - Probing
#    - Telling
#    - Generic
#
# 10. NEXT ACTION SUBCATEGORY:
#     Choose **exactly one** of the following, depending on the category:
#
#     **Focus**:
#     - "Seek Next Step"
#     - "Confirm Calculation"
#     - "Re-direct to Sub-Problem"
#     - "Highlight Missing Info"
#
#     **Probing**:
#     - "Ask for Explanation"
#     - "Seek Self-Correction"
#     - "Hypothetical Variation"
#     - "Check Understanding/Concept"
#     - "Encourage Comparison"
#
#     **Telling**:
#     - "Partial Reveal (Strategy)"
#     - "Full Reveal (Answer)"
#     - "Corrective Explanation"
#
#     **Generic**:
#     - "Greeting/Farewell"
#     - "Acknowledgment/Praise"
#     - "Summarize Progress"
#     - "General Inquiry/Filler"
#
# FORMAT YOUR RESPONSE AS JSON:
# {
#   "state": {
#     "misconception_type": "one_of_the_six_types",
#     "listen_to_feedback": 0 or 1,
#     "problem_progress": integer_between_0_and_100,
#     "problem_concept": "specific_math_concept",
#     "conversation_turn": integer,
#     "correct_solution": 0 or 1,
#     "problem_difficulty": integer_between_1_and_3
#   },
#   "action": {
#     "next_action_hint_strength": integer_between_0_and_4,
#     "next_action_category": "Focus/Probing/Telling/Generic",
#     "next_action_subcategory": "pick_the_exact_one_subcategory_name"
#   }
# }
#
# IMPORTANT:
# - Return ONLY the JSON object with no additional explanation
# - All numeric fields must be valid integers

# %%
state_df
# Out:
#                                                 question  \
# 0      Nancy is filling an aquarium for her fish. She...
# 1      Nancy is filling an aquarium for her fish. She...
# 2      Nancy is filling an aquarium for her fish. She...
# 3      John is very unfit and decides to work up to d...
# 4      John is very unfit and decides to work up to d...
# ...                                                  ...
# 20149  Andy is checking to see if all the cars in the...
# 20150  Andy is checking to see if all the cars in the...
# 20151  Andy is checking to see if all the cars in the...
# 20152  Andy is checking to see if all the cars in the...
# 20153  Andy is checking to see if all the cars in the...
#
#                                             ground_truth  \
# 0      First calculate the volume of the aquarium by ...
# 1      First calculate the volume of the aquarium by ...
# 2      First calculate the volume of the aquarium by ...
# 3      He needs to do 15*3=45 progressions\nThat will...
# 4      He needs to do 15*3=45 progressions\nThat will...
# ...                                                  ...
# 20149  First find how many cars have valid tickets: 7...
# 20150  First find how many cars have valid tickets: 7...
# 20151  First find how many cars have valid tickets: 7...
# 20152  First find how many cars have valid tickets: 7...
# 20153  First find how many cars have valid tickets: 7...
#
#                               student_incorrect_solution  \
# 0      The aquarium has a volume of 4 x 6 x 3 = 72 cu...
# 1      The aquarium has a volume of 4 x 6 x 3 = 72 cu...
# 2      The aquarium has a volume of 4 x 6 x 3 = 72 cu...
# 3      To get to 15 reps, John will take 15 - 1 = 14 ...
# 4      To get to 15 reps, John will take 15 - 1 = 14 ...
# ...                                                  ...
# 20149  75% of the cars have valid tickets, so 100%-75...
# 20150  75% of the cars have valid tickets, so 100%-75...
# 20151  75% of the cars have valid tickets, so 100%-75...
# 20152  75% of the cars have valid tickets, so 100%-75...
# 20153  75% of the cars have valid tickets, so 100%-75...
#
#                                          student_profile  \
# 0      Steven is a 7th grade student. He has difficul...
# 1      Steven is a 7th grade student. He has difficul...
# 2      Steven is a 7th grade student. He has difficul...
# 3      Stephanie is a 7th grade student. She has diff...
# 4      Stephanie is a 7th grade student. She has diff...
# ...                                                  ...
# 20149  Stephanie is a 7th grade student. She struggle...
# 20150  Stephanie is a 7th grade student. She struggle...
# 20151  Stephanie is a 7th grade student. She struggle...
# 20152  Stephanie is a 7th grade student. She struggle...
# 20153  Stephanie is a 7th grade student. She struggle...
#
#                                             conversation  \
# 0      Teacher: (probing)Steven, If you had 4 of some...
# 1      Teacher: (probing)Steven, If you had 4 of some...
# 2      Teacher: (probing)Steven, If you had 4 of some...
# 3      Teacher: (probing)Stephanie, How many days wil...
# 4      Teacher: (probing)Stephanie, How many days wil...
# ...                                                  ...
# 20149  Teacher: (generic)Hi, could you please walk me...
# 20150  Teacher: (generic)Hi, could you please walk me...
# 20151  Teacher: (generic)Hi, could you please walk me...
# 20152  Teacher: (generic)Hi, could you please walk me...
# 20153  Teacher: (generic)Hi, could you please walk me...
#
#                                                    state  \
# 0                                              [, START]
# 1      [Teacher: (probing)Steven, If you had 4 of som...
# 2      [Teacher: (probing)So if Nancy triples the 18 ...
# 3                                              [, START]
# 4      [Teacher: (probing)Stephanie, How many days wi...
# ...                                                  ...
# 20149  [Teacher: (generic)Hi, could you please walk m...
# 20150  [Teacher: (focus)That doesn't seem to be corre...
# 20151  [Teacher: (focus)Great. The question now says ...
# 20152  [Teacher: (focus)That's wonderful. So now what...
# 20153  [Teacher: (generic)There's your answer. I hope...
#
#                                              action_text  done  \
# 0      Teacher: (probing)Steven, If you had 4 of some...     0
# 1      Teacher: (probing)So if Nancy triples the 18 c...     0
# 2                     Teacher: (generic)Exactly correct!     1
# 3      Teacher: (probing)Stephanie, How many days wil...     0
# 4      Teacher: (probing)So how many days will it tak...     0
# ...                                                  ...   ...
# 20149  Teacher: (focus)That doesn't seem to be correc...     0
# 20150  Teacher: (focus)Great. The question now says t...     0
# 20151  Teacher: (focus)That's wonderful. So now what ...     0
# 20152  Teacher: (generic)There's your answer. I hope ...     0
# 20153                                                NaN     1
#
#                                               full_state  convo_turn  \
# 0                                              [, START]           1
# 1      [Teacher: (probing)Steven, If you had 4 of som...           2
# 2      [Teacher: (probing)So if Nancy triples the 18 ...           3
# 3                                              [, START]           1
# 4      [Teacher: (probing)Stephanie, How many days wi...           2
# ...                                                  ...         ...
# 20149  [Teacher: (generic)Hi, could you please walk m...           2
# 20150  [Teacher: (focus)That doesn't seem to be corre...           3
# 20151  [Teacher: (focus)Great. The question now says ...           4
# 20152  [Teacher: (focus)That's wonderful. So now what...           5
# 20153  [Teacher: (generic)There's your answer. I hope...           6
#
#                                                old_state
# 0                                                  START
# 1                  Steven: I would have 12 of something.
# 2         Steven: She would have 54 cubic feet of water.
# 3                                                  START
# 4      Student: It will take one day to do one step, ...
# ...                                                  ...
# 20149  Student: Sure, I said that 75% of the cars hav...
# 20150  Student: Sure. I said that 75% of the cars hav...
# 20151  Student: Yes, 1/5th of 225 cars is (1/5)*225 =...
# 20152  Student: There are 225 cars with valid tickets...
# 20153      Student: Yes, I got it. Thanks for your help!
#
# [20154 rows x 11 columns]

# %%
state_df["conversation"][0]
# Out:
# 'Teacher: (probing)Steven, If you had 4 of something and tripled that amount, how much would you have?|EOM|Steven: I would have 12 of something.|EOM|Teacher: (probing)So if Nancy triples the 18 cubic feet of water, how much would she have?|EOM|Steven: She would have 54 cubic feet of water.|EOM|Teacher: (generic)Exactly correct!'

# %%
from ollama import Client
client = Client(
  host='http://localhost:11434',
  headers = {
        "Content-Type": "application/json"
    }
)


def extract_json(text):
    """
    Extract JSON object from text that might contain additional content,
    then validate whether it fits the expected schema.

    Returns:
        dict or None: Extracted JSON object if valid, otherwise None
    """
    print(f"Raw text (last 200 chars): {text[-200:] if len(text) > 200 else text}")

    # 1) Direct JSON loading attempt
    try:
        data = json.loads(text)
        if validate_schema(data):
            return data
    except json.JSONDecodeError:
        pass

    # 2) Regex pattern (brute-force) for JSON blocks
    json_pattern = r'\s*(\{[^{}]*(?:\{[^{}]*\}[^{}]*)*\})\s*'
    matches = re.findall(json_pattern, text, re.DOTALL)
    if matches:
        # Try from the last match backward (often the last is the full JSON)
        for potential_json in reversed(matches):
            try:
                data = json.loads(potential_json)
                if validate_schema(data):
                    return data
            except json.JSONDecodeError:
                continue

    # 3) Aggressive brace matching from the last '{' found
    try:
        start_idx = text.rfind('{')
        if start_idx != -1:
            brace_count = 1
            i = start_idx + 1
            while i < len(text) and brace_count > 0:
                if text[i] == '{':
                    brace_count += 1
                elif text[i] == '}':
                    brace_count -= 1
                i += 1

            if brace_count == 0:
                json_str = text[start_idx:i]
                data = json.loads(json_str)
                if validate_schema(data):
                    return data
    except Exception as e:
        print(f"Error in aggressive JSON extraction: {str(e)}")

    # 4) Fallback pattern with your required fields (if you want to be very specific)
    # Adjusted to include problem_difficulty
    pattern = (
        r'\{\s*"state":\s*\{[^}]*\},\s*"action":\s*\{[^}]*\}\s*\}'
    )
    matches = re.findall(pattern, text, re.DOTALL)
    if matches:
        for potential_json in matches:
            try:
                data = json.loads(potential_json.strip())
                if validate_schema(data):
                    return data
            except json.JSONDecodeError:
                continue

    print("All extraction methods failed or schema validation failed. Returning None.")
    return None


def validate_schema(data):
    """
    Validate the JSON structure to ensure it contains the right keys and
    that numeric fields are truly numeric and in the right range, etc.
    """
    # Top-level keys we expect
    if not isinstance(data, dict):
        return False

    if "state" not in data or "action" not in data:
        return False

    # Validate 'state' keys
    state = data["state"]
    required_state_keys = [
        "misconception_type", "listen_to_feedback", "problem_progress",
        "problem_concept", "conversation_turn", "correct_solution",
        "problem_difficulty"
    ]
    for key in required_state_keys:
        if key not in state:
            return False

    # Check numeric fields
    if not isinstance(state["listen_to_feedback"], int):
        return False
    if state["listen_to_feedback"] not in (0, 1):
        return False

    if not isinstance(state["problem_progress"], int):
        return False
    if not (0 <= state["problem_progress"] <= 100):
        return False

    if not isinstance(state["conversation_turn"], int):
        return False

    if not isinstance(state["correct_solution"], int):
        return False
    if state["correct_solution"] not in (0, 1):
        return False

    # Check problem_difficulty
    if not isinstance(state["problem_difficulty"], int):
        return False
    if not (1 <= state["problem_difficulty"] <= 5):
        return False

    # Validate 'action' keys
    action = data["action"]
    required_action_keys = [
        "next_action_hint_strength", "next_action_category", "next_action_subcategory"
    ]
    for key in required_action_keys:
        if key not in action:
            return False

    # Check action numeric fields
    if not isinstance(action["next_action_hint_strength"], int):
        return False
    # Change this line in validate_schema()
    if not (0 <= action["next_action_hint_strength"] <= 4):
        return False

    # Check action category
    valid_action_categories = ["Focus", "Probing", "Telling", "Generic"]
    if action["next_action_category"] not in valid_action_categories:
        return False

    # next_action_subcategory: up to you how strictly to validate
    # For example, if Focus: could be one of [Seek Next Step, Confirm Calculation, etc.]
    # We'll do minimal checking here
    if not isinstance(action["next_action_subcategory"], str):
        return False

    return True


# Example script usage:
processed = 0
successful = 0
failed = 0

for i, row in state_df.iterrows():
    # Gather your fields
    question = row.get("question", "")
    correct_solution = row.get("ground_truth", "")
    student_profile = row.get("student_profile", "")
    current_conversation_state = row.get("state", "")
    conversation_turn = row.get("convo_turn", "")
    action_text = row.get("action_text", "")

    # Updated prompt with problem_difficulty added
    if i == 0:
        prompt = f"""
You are analyzing math tutoring sessions to extract features for an AI tutor.

CONTEXT:
- Question: {question}
- Correct solution: {correct_solution}
- Student profile: {student_profile}
- Current conversation: {current_conversation_state}
- Conversation turn: {conversation_turn}
- Next action text: {action_text}

TASK:
Extract the following features from this tutoring interaction:

1. MISCONCEPTION TYPE - This classification MUST be determined SOLELY from the student profile, not from the conversation. It represents the student's core misunderstanding and should be CONSISTENT across all interactions with this same student. Choose ONE of these types based only on the student profile description:
- operation_error: Student applies the wrong operation (e.g., adding instead of multiplying)
- number_fact_error: Student makes errors in basic number facts (e.g., multiplication tables)
- variable_meaning_error: Student misunderstands what variables represent
- conceptual_error: Student has fundamental misconception about a math concept
- calculation_error: Student makes arithmetic errors during calculation
- problem_interpretation_error: Student misunderstands what the problem is asking

2. LISTEN TO FEEDBACK:
   - 1 if the student has incorporated the teacher's feedback in the current conversation state
   - 0 if not

3. PROBLEM PROGRESS - Numerical estimate (0-100) of how close, given the student's current conversation state, the student is to the correct solution. For example:
  - 0: No progress/completely wrong approach
  - 25: Beginning to understand but major errors remain
  - 50: Halfway to solution with some key insights
  - 75: Minor errors but mostly correct approach
  - 100: Complete and correct solution
  (You may use any value between 0-100, not just the examples above)

4. PROBLEM CONCEPT:
   The specific math domain/concept being tested. Based on the question, choose the one most relevant concept: "basic_arithmetic", "fractions_decimals_and_percents", "ratios_proportions_and_rates", "measurement_and_geometry", "counting_and_combinatorics", "money_and_finance", or "algebraic_relationships".

5. CONVERSATION TURN:
   The number of exchanges so far.

6. CORRECT SOLUTION:
   - 0 if the student's final answer is incorrect
   - 1 if correct

7. PROBLEM DIFFICULTY (1-3):
   Rate how difficult the math question is on a scale from 1 to 5, where:
   - 1 = Very easy, basic concepts, straightforward approach
   - 2 = Moderate, requires some thought, multiple steps
   - 3 = Challenging, complex approach, requires deeper understanding

8. NEXT ACTION HINT STRENGTH (0-4):
   How strong is the teacher's hint? (0=very minimal hint, 4=essentially giving away the entire solution)

9. NEXT ACTION CATEGORY:
   - Focus
   - Probing
   - Telling
   - Generic

10. NEXT ACTION SUBCATEGORY:
    Choose **exactly one** of the following, depending on the category:

    **Focus**:
    - "Seek Next Step"
    - "Confirm Calculation"
    - "Re-direct to Sub-Problem"
    - "Highlight Missing Info"

    **Probing**:
    - "Ask for Explanation"
    - "Seek Self-Correction"
    - "Hypothetical Variation"
    - "Check Understanding/Concept"
    - "Encourage Comparison"

    **Telling**:
    - "Partial Reveal (Strategy)"
    - "Full Reveal (Answer)"
    - "Corrective Explanation"

    **Generic**:
    - "Greeting/Farewell"
    - "Acknowledgment/Praise"
    - "Summarize Progress"
    - "General Inquiry/Filler"

FORMAT YOUR RESPONSE AS JSON:
{{
  "state": {{
    "misconception_type": "one_of_the_six_types",
    "listen_to_feedback": 0 or 1,
    "problem_progress": integer_between_0_and_100,
    "problem_concept": "specific_math_concept",
    "conversation_turn": integer,
    "correct_solution": 0 or 1,
    "problem_difficulty": integer_between_1_and_3
  }},
  "action": {{
    "next_action_hint_strength": integer_between_0_and_4,
    "next_action_category": "Focus/Probing/Telling/Generic",
    "next_action_subcategory": "pick_the_exact_one_subcategory_name"
  }}
}}

IMPORTANT:
- Return ONLY the JSON object with no additional explanation
- All numeric fields must be valid integers
"""
    else:
        prompt = f"""
You are analyzing math tutoring sessions to extract features for an AI tutor as you did before.

CONTEXT:
- Question: {question}
- Correct solution: {correct_solution}
- Student profile: {student_profile}
- Current conversation: {current_conversation_state}
- Conversation turn: {conversation_turn}
- Next action text: {action_text}

FORMAT YOUR RESPONSE AS JSON:
{{
  "state": {{
    "misconception_type": "one_of_the_six_types",
    "listen_to_feedback": 0 or 1,
    "problem_progress": integer_between_0_and_100,
    "problem_concept": "specific_math_concept",
    "conversation_turn": integer,
    "correct_solution": 0 or 1,
    "problem_difficulty": integer_between_1_and_3
  }},
  "action": {{
    "next_action_hint_strength": integer_between_0_and_4,
    "next_action_category": "Focus/Probing/Telling/Generic",
    "next_action_subcategory": "pick_the_exact_one_subcategory_name"
  }}
}}

IMPORTANT:
- Return ONLY the JSON object with no additional explanation
- All numeric fields must be valid integers
"""

    # Example payload structure; adjust to your actual usage:
    # payload = {
    #     "model": "gpt-4-0613",
    #     "messages": [
    #         {"role": "user", "content": prompt.strip()}
    #     ],
    #     "max_tokens": 400
    # }

    

    processed += 1

    try:
        print(f"Processing row {i} ...")
        
        response = client.chat(model='gemma3:27b', messages=[
              {
                'role': 'user',
                "content": prompt.strip()
              },
            ])
        
        raw_response = response['message']['content']

        if i == 0:
            print(prompt.strip())
            print(raw_response)
            
        # Store raw response
        state_df.loc[i, "raw_model_response"] = raw_response

        data = extract_json(raw_response)
        if data is not None:
            # Validate & store relevant fields
            # Because we do more thorough checks in validate_schema,
            # we can now simply parse them into your df if you like.

            # Flatten 'state' ...
            state_part = data.get("state", {})
            state_df.loc[i, "misconception_type"] = state_part.get("misconception_type", "")
            state_df.loc[i, "listen_to_feedback"] = state_part.get("listen_to_feedback", 0)
            state_df.loc[i, "problem_progress"] = state_part.get("problem_progress", 0)
            state_df.loc[i, "problem_concept"] = state_part.get("problem_concept", "")
            state_df.loc[i, "conversation_turn"] = state_part.get("conversation_turn", 0)
            state_df.loc[i, "correct_solution"] = state_part.get("correct_solution", 0)
            state_df.loc[i, "problem_difficulty"] = state_part.get("problem_difficulty", 3)  # Default to middle value
            # state_df.loc[i, "reasoning"] = state_part.get("reasoning", "")

            # Flatten 'action' ...
            action_part = data.get("action", {})
            state_df.loc[i, "next_action_hint_strength"] = action_part.get("next_action_hint_strength", 1)
            state_df.loc[i, "next_action_category"] = action_part.get("next_action_category", "")
            state_df.loc[i, "next_action_subcategory"] = action_part.get("next_action_subcategory", "")

            print(f"Successfully extracted JSON for row {i}")
            successful += 1
        else:
            state_df.loc[i, "extraction_failed"] = True
            print(f"Row {i}: Failed to extract valid JSON.")
            failed += 1

        # Save partial progress every 50 rows
        if i % 50 == 0:
            state_df.to_csv("mathdial_gemma3_27b_in_progress.csv", index=False)
            print(f"Progress saved at row {i}.")

    except Exception as e:
        state_df.loc[i, "error_message"] = str(e)
        state_df.loc[i, "extraction_failed"] = True
        print(f"Error processing row {i}: {str(e)}")
        failed += 1

    print("--------------------------------------------------------")

# Final save
state_df.to_csv("mathdial_gemma3_27b_complete.csv", index=False)

print(f"\nProcessing complete:")
print(f"Total rows processed: {processed}")
print(f"Successful extractions: {successful}")
print(f"Failed extractions: {failed}")
if processed > 0:
    print(f"Success rate: {successful/processed*100:.2f}%")
else:
    print("No rows processed.")
# Out:
# Processing row 0 ...
# You are analyzing math tutoring sessions to extract features for an AI tutor.
#
# CONTEXT:
# - Question: Nancy is filling an aquarium for her fish. She fills it halfway and goes to answer the door. While she's gone, her cat knocks the aquarium over and spills half the water in it. Then Nancy comes back and triples the amount of water in the aquarium. If the aquarium is 4 feet long, 6 feet wide, and 3 feet high, how many cubic feet of water are in the aquarium?
# - Correct solution: First calculate the volume of the aquarium by multiplying its length, width and height: 4 ft * 6 ft * 3 ft = 72 cubic ft
# Then figure out what proportion of the aquarium is full after the cat knocks it over: 1/2 * 1/2 = 1/4
# Then figure out what proportion of the aquarium is full after Nancy refills it: 3 * 1/4 = 3/4
# Now multiply the proportion of the aquarium that's full by the aquarium's volume to find out how much water is in it: 72 cubic ft * 3/4 = 54 cubic ft
#  54
# - Student profile: Steven is a 7th grade student. He has difficulty determining which pieces of information are relevant and which are irrelevant to solving the problem.
# - Current conversation: ['', 'START']
# - Conversation turn: 1
# - Next action text: Teacher: (probing)Steven, If you had 4 of something and tripled that amount, how much would you have?
#
# TASK:
# Extract the following features from this tutoring interaction:
#
# 1. MISCONCEPTION TYPE - This classification MUST be determined SOLELY from the student profile, not from the conversation. It represents the student's core misunderstanding and should be CONSISTENT across all interactions with this same student. Choose ONE of these types based only on the student profile description:
# - operation_error: Student applies the wrong operation (e.g., adding instead of multiplying)
# - number_fact_error: Student makes errors in basic number facts (e.g., multiplication tables)
# - variable_meaning_error: Student misunderstands what variables represent
# - conceptual_error: Student has fundamental misconception about a math concept
# - calculation_error: Student makes arithmetic errors during calculation
# - problem_interpretation_error: Student misunderstands what the problem is asking
#
# 2. LISTEN TO FEEDBACK:
#    - 1 if the student has incorporated the teacher's feedback in the current conversation state
#    - 0 if not
#
# 3. PROBLEM PROGRESS - Numerical estimate (0-100) of how close, given the student's current conversation state, the student is to the correct solution. For example:
#   - 0: No progress/completely wrong approach
#   - 25: Beginning to understand but major errors remain
#   - 50: Halfway to solution with some key insights
#   - 75: Minor errors but mostly correct approach
#   - 100: Complete and correct solution
#   (You may use any value between 0-100, not just the examples above)
#
# 4. PROBLEM CONCEPT:
#    The specific math domain/concept being tested. Based on the question, choose the one most relevant concept: "basic_arithmetic", "fractions_decimals_and_percents", "ratios_proportions_and_rates", "measurement_and_geometry", "counting_and_combinatorics", "money_and_finance", or "algebraic_relationships".
#
# 5. CONVERSATION TURN:
#    The number of exchanges so far.
#
# 6. CORRECT SOLUTION:
#    - 0 if the student's final answer is incorrect
#    - 1 if correct
#
# 7. PROBLEM DIFFICULTY (1-3):
#    Rate how difficult the math question is on a scale from 1 to 5, where:
#    - 1 = Very easy, basic concepts, straightforward approach
#    - 2 = Moderate, requires some thought, multiple steps
#    - 3 = Challenging, complex approach, requires deeper understanding
#
# 8. NEXT ACTION HINT STRENGTH (0-4):
#    How strong is the teacher's hint? (0=very minimal hint, 4=essentially giving away the entire solution)
#
# 9. NEXT ACTION CATEGORY:
#    - Focus
#    - Probing
#    - Telling
#    - Generic
#
# 10. NEXT ACTION SUBCATEGORY:
#     Choose **exactly one** of the following, depending on the category:
#
#     **Focus**:
#     - "Seek Next Step"
#     - "Confirm Calculation"
#     - "Re-direct to Sub-Problem"
#     - "Highlight Missing Info"
#
#     **Probing**:
#     - "Ask for Explanation"
#     - "Seek Self-Correction"
#     - "Hypothetical Variation"
#     - "Check Understanding/Concept"
#     - "Encourage Comparison"
#
#     **Telling**:
#     - "Partial Reveal (Strategy)"
#     - "Full Reveal (Answer)"
#     - "Corrective Explanation"
#
#     **Generic**:
#     - "Greeting/Farewell"
#     - "Acknowledgment/Praise"
#     - "Summarize Progress"
#     - "General Inquiry/Filler"
#
# FORMAT YOUR RESPONSE AS JSON:
# {
#   "state": {
#     "misconception_type": "one_of_the_six_types",
#     "listen_to_feedback": 0 or 1,
#     "problem_progress": integer_between_0_and_100,
#     "problem_concept": "specific_math_concept",
#     "conversation_turn": integer,
#     "correct_solution": 0 or 1,
#     "problem_difficulty": integer_between_1_and_3
#   },
#   "action": {
#     "next_action_hint_strength": integer_between_0_and_4,
#     "next_action_category": "Focus/Probing/Telling/Generic",
#     "next_action_subcategory": "pick_the_exact_one_subcategory_name"
#   }
# }
#
# IMPORTANT:
# - Return ONLY the JSON object with no additional explanation
# - All numeric fields must be valid integers
# ```json
# {
#   "state": {
#     "misconception_type": "problem_interpretation_error",
#     "listen_to_feedback": 0,
#     "problem_progress": 0,
#     "problem_concept": "basic_arithmetic",
#     "conversation_turn": 1,
#     "correct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "Check Understanding/Concept"
#   }
# }
# ```
# Raw text (last 200 chars): on": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "Check Understanding/Concept"
#   }
# }
# ```
# Successfully extracted JSON for row 0
# Progress saved at row 0.
# --------------------------------------------------------
# Processing row 1 ...
# Raw text (last 200 chars): tion": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_intermediate_step"
#   }
# }
# ```
# Successfully extracted JSON for row 1
# --------------------------------------------------------
# Processing row 2 ...
# Raw text (last 200 chars): "correct_solution": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 0,
#     "next_action_category": "Generic",
#     "next_action_subcategory": "confirmation"
#   }
# }
# ```
# Successfully extracted JSON for row 2
# --------------------------------------------------------
# Processing row 3 ...
# Raw text (last 200 chars): olution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "identify_relevant_info"
#   }
# }
# ```
# Successfully extracted JSON for row 3
# --------------------------------------------------------
# Processing row 4 ...
# Raw text (last 200 chars): 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "calculate_from_prior_information"
#   }
# }
# ```
# Successfully extracted JSON for row 4
# --------------------------------------------------------
# Processing row 5 ...
# Raw text (last 200 chars): ": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "identify_relevant_information"
#   }
# }
# ```
# Successfully extracted JSON for row 5
# --------------------------------------------------------
# Processing row 6 ...
# Raw text (last 200 chars): t_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "correct_calculation"
#   }
# }
# ```
# Successfully extracted JSON for row 6
# --------------------------------------------------------
# Processing row 7 ...
# Raw text (last 200 chars): rect_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "isolate_variable"
#   }
# }
# ```
# Successfully extracted JSON for row 7
# --------------------------------------------------------
# Processing row 8 ...
# Raw text (last 200 chars): ion": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "identify_calculation_error"
#   }
# }
# ```
# Successfully extracted JSON for row 8
# --------------------------------------------------------
# Processing row 9 ...
# Raw text (last 200 chars): ct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 3,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "direct_instruction"
#   }
# }
# ```
# Successfully extracted JSON for row 9
# --------------------------------------------------------
# Processing row 10 ...
# Raw text (last 200 chars): correct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 3,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "direct_answer"
#   }
# }
# ```
# Successfully extracted JSON for row 10
# --------------------------------------------------------
# Processing row 11 ...
# Raw text (last 200 chars): ect_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "direct_correction"
#   }
# }
# ```
# Successfully extracted JSON for row 11
# --------------------------------------------------------
# Processing row 12 ...
# Raw text (last 200 chars): rrect_solution": 0,
#     "problem_difficulty": 1
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "point_out_error"
#   }
# }
# ```
# Successfully extracted JSON for row 12
# --------------------------------------------------------
# Processing row 13 ...
# Raw text (last 200 chars): ": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "identify_relevant_information"
#   }
# }
# ```
# Successfully extracted JSON for row 13
# --------------------------------------------------------
# Processing row 14 ...
# Raw text (last 200 chars): on": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_initial_information"
#   }
# }
# ```
# Successfully extracted JSON for row 14
# --------------------------------------------------------
# Processing row 15 ...
# Raw text (last 200 chars):  "correct_solution": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "recall_fact"
#   }
# }
# ```
# Successfully extracted JSON for row 15
# --------------------------------------------------------
# Processing row 16 ...
# Raw text (last 200 chars): on": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "focus_on_relevant_information"
#   }
# }
# ```
# Successfully extracted JSON for row 16
# --------------------------------------------------------
# Processing row 17 ...
# Raw text (last 200 chars): ution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_overall_strategy"
#   }
# }
# ```
# Successfully extracted JSON for row 17
# --------------------------------------------------------
# Processing row 18 ...
# Raw text (last 200 chars):  "correct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "check_units"
#   }
# }
# ```
# Successfully extracted JSON for row 18
# --------------------------------------------------------
# Processing row 19 ...
# Raw text (last 200 chars): correct_solution": 0,
#     "problem_difficulty": 1
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "retrieve_fact"
#   }
# }
# ```
# Successfully extracted JSON for row 19
# --------------------------------------------------------
# Processing row 20 ...
# Raw text (last 200 chars): t_solution": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_information"
#   }
# }
# ```
# Successfully extracted JSON for row 20
# --------------------------------------------------------
# Processing row 21 ...
# Raw text (last 200 chars):  "correct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "recall_fact"
#   }
# }
# ```
# Successfully extracted JSON for row 21
# --------------------------------------------------------
# Processing row 22 ...
# Raw text (last 200 chars):     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Focus/Probing/Telling/Generic",
#     "next_action_subcategory": "retrieve_fact"
#   }
# }
# ```
# All extraction methods failed or schema validation failed. Returning None.
# Row 22: Failed to extract valid JSON.
# --------------------------------------------------------
# Processing row 23 ...
# Raw text (last 200 chars): rrect_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "combine_distances"
#   }
# }
# ```
# Successfully extracted JSON for row 23
# --------------------------------------------------------
# Processing row 24 ...
# Raw text (last 200 chars):  "correct_solution": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 0,
#     "next_action_category": "Generic",
#     "next_action_subcategory": "affirmation"
#   }
# }
# ```
# Successfully extracted JSON for row 24
# --------------------------------------------------------
# Processing row 25 ...
# Raw text (last 200 chars): n": 0,
#     "problem_difficulty": 1
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "extract_relevant_information"
#   }
# }
# ```
# Successfully extracted JSON for row 25
# --------------------------------------------------------
# Processing row 26 ...
# Raw text (last 200 chars): t_solution": 0,
#     "problem_difficulty": 1
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_calculation"
#   }
# }
# ```
# Successfully extracted JSON for row 26
# --------------------------------------------------------
# Processing row 27 ...
# Raw text (last 200 chars): rrect_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_details"
#   }
# }
# ```
# Successfully extracted JSON for row 27
# --------------------------------------------------------
# Processing row 28 ...
# Raw text (last 200 chars): olution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "clarify_total_distance"
#   }
# }
# ```
# Successfully extracted JSON for row 28
# --------------------------------------------------------
# Processing row 29 ...
# Raw text (last 200 chars): olution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_daily_distance"
#   }
# }
# ```
# Successfully extracted JSON for row 29
# --------------------------------------------------------
# Processing row 30 ...
# Raw text (last 200 chars): ct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "direct_instruction"
#   }
# }
# ```
# Successfully extracted JSON for row 30
# --------------------------------------------------------
# Processing row 31 ...
# Raw text (last 200 chars): rrect_solution": 1,
#     "problem_difficulty": 1
#   },
#   "action": {
#     "next_action_hint_strength": 0,
#     "next_action_category": "Generic",
#     "next_action_subcategory": "acknowledgement"
#   }
# }
# ```
# Successfully extracted JSON for row 31
# --------------------------------------------------------
# Processing row 32 ...
# Raw text (last 200 chars): lution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "elicit_initial_approach"
#   }
# }
# ```
# Successfully extracted JSON for row 32
# --------------------------------------------------------
# Processing row 33 ...
# Raw text (last 200 chars): n": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "check_understanding_of_units"
#   }
# }
# ```
# Successfully extracted JSON for row 33
# --------------------------------------------------------
# Processing row 34 ...
# Raw text (last 200 chars): on": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "redirect_to_given_information"
#   }
# }
# ```
# Successfully extracted JSON for row 34
# --------------------------------------------------------
# Processing row 35 ...
# Raw text (last 200 chars): olution": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 0,
#     "next_action_category": "Generic",
#     "next_action_subcategory": "positive_reinforcement"
#   }
# }
# ```
# Successfully extracted JSON for row 35
# --------------------------------------------------------
# Processing row 36 ...
# Raw text (last 200 chars):    "correct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 0,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "show_work"
#   }
# }
# ```
# Successfully extracted JSON for row 36
# --------------------------------------------------------
# Processing row 37 ...
# Raw text (last 200 chars): ": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_weeks_before_midterms"
#   }
# }
# ```
# Successfully extracted JSON for row 37
# --------------------------------------------------------
# Processing row 38 ...
# Raw text (last 200 chars): tion": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "identify_arithmetic_error"
#   }
# }
# ```
# Successfully extracted JSON for row 38
# --------------------------------------------------------
# Processing row 39 ...
# Raw text (last 200 chars): rect_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "review_calculation"
#   }
# }
# ```
# Successfully extracted JSON for row 39
# --------------------------------------------------------
# Processing row 40 ...
# Raw text (last 200 chars): ": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "check_subtraction_or_division"
#   }
# }
# ```
# Successfully extracted JSON for row 40
# --------------------------------------------------------
# Processing row 41 ...
# Raw text (last 200 chars): t_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 3,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "explicit_correction"
#   }
# }
# ```
# Successfully extracted JSON for row 41
# --------------------------------------------------------
# Processing row 42 ...
# Raw text (last 200 chars): tion": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "clarify_subtraction_order"
#   }
# }
# ```
# Successfully extracted JSON for row 42
# --------------------------------------------------------
# Processing row 43 ...
# Raw text (last 200 chars): solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "provide_solution_step"
#   }
# }
# ```
# Successfully extracted JSON for row 43
# --------------------------------------------------------
# Processing row 44 ...
# Raw text (last 200 chars): solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "step_by_step_solution"
#   }
# }
# ```
# Successfully extracted JSON for row 44
# --------------------------------------------------------
# Processing row 45 ...
# Raw text (last 200 chars):  "correct_solution": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 0,
#     "next_action_category": "Generic",
#     "next_action_subcategory": "affirmation"
#   }
# }
# ```
# Successfully extracted JSON for row 45
# --------------------------------------------------------
# Processing row 46 ...
# Raw text (last 200 chars): solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 0,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "elicit_initial_approach"
#   }
# }
# ```
# Successfully extracted JSON for row 46
# --------------------------------------------------------
# Processing row 47 ...
# Raw text (last 200 chars): lution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "clarify_student_reasoning"
#   }
# }
# ```
# Successfully extracted JSON for row 47
# --------------------------------------------------------
# Processing row 48 ...
# Raw text (last 200 chars): n": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "connect_to_original_question"
#   }
# }
# ```
# Successfully extracted JSON for row 48
# --------------------------------------------------------
# Processing row 49 ...
# Raw text (last 200 chars): ect_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_reasoning"
#   }
# }
# ```
# Successfully extracted JSON for row 49
# --------------------------------------------------------
# Processing row 50 ...
# Raw text (last 200 chars): n": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "connect_to_initial_condition"
#   }
# }
# ```
# Successfully extracted JSON for row 50
# Progress saved at row 50.
# --------------------------------------------------------
# Processing row 51 ...
# Raw text (last 200 chars): correct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "direct_question"
#   }
# }
# ```
# Successfully extracted JSON for row 51
# --------------------------------------------------------
# Processing row 52 ...
# Raw text (last 200 chars):   "correct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 3,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "spot_error"
#   }
# }
# ```
# Successfully extracted JSON for row 52
# --------------------------------------------------------
# Processing row 53 ...
# Raw text (last 200 chars): ct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 3,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "direct_explanation"
#   }
# }
# ```
# Successfully extracted JSON for row 53
# --------------------------------------------------------
# Processing row 54 ...
# Raw text (last 200 chars): "correct_solution": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 0,
#     "next_action_category": "Generic",
#     "next_action_subcategory": "confirmation"
#   }
# }
# ```
# Successfully extracted JSON for row 54
# --------------------------------------------------------
# Processing row 55 ...
# Raw text (last 200 chars): em_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Focus/Probing/Telling/Generic",
#     "next_action_subcategory": "elicit_initial_approach"
#   }
# }
# ```
# All extraction methods failed or schema validation failed. Returning None.
# Row 55: Failed to extract valid JSON.
# --------------------------------------------------------
# Processing row 56 ...
# Raw text (last 200 chars):  "correct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "check_units"
#   }
# }
# ```
# Successfully extracted JSON for row 56
# --------------------------------------------------------
# Processing row 57 ...
# Raw text (last 200 chars): orrect_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "simplify_problem"
#   }
# }
# ```
# Successfully extracted JSON for row 57
# --------------------------------------------------------
# Processing row 58 ...
# Raw text (last 200 chars):  "correct_solution": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 0,
#     "next_action_category": "Generic",
#     "next_action_subcategory": "affirmation"
#   }
# }
# ```
# Successfully extracted JSON for row 58
# --------------------------------------------------------
# Processing row 59 ...
# Raw text (last 200 chars):   "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Focus/Probing/Telling/Generic",
#     "next_action_subcategory": "elicit_approach"
#   }
# }
# ```
# All extraction methods failed or schema validation failed. Returning None.
# Row 59: Failed to extract valid JSON.
# --------------------------------------------------------
# Processing row 60 ...
# Raw text (last 200 chars): lution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "identify_calculation_step"
#   }
# }
# ```
# Successfully extracted JSON for row 60
# --------------------------------------------------------
# Processing row 61 ...
# Raw text (last 200 chars): on": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "check_understanding_of_step"
#   }
# }
# ```
# Successfully extracted JSON for row 61
# --------------------------------------------------------
# Processing row 62 ...
# Raw text (last 200 chars): correct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "check_your_work"
#   }
# }
# ```
# Successfully extracted JSON for row 62
# --------------------------------------------------------
# Processing row 63 ...
# Raw text (last 200 chars): ion": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "identify_calculation_error"
#   }
# }
# ```
# Successfully extracted JSON for row 63
# --------------------------------------------------------
# Processing row 64 ...
# Raw text (last 200 chars): ct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "connect_calculations"
#   }
# }
# ```
# Successfully extracted JSON for row 64
# --------------------------------------------------------
# Processing row 65 ...
# Raw text (last 200 chars): ct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "compare_calculations"
#   }
# }
# ```
# Successfully extracted JSON for row 65
# --------------------------------------------------------
# Processing row 66 ...
# Raw text (last 200 chars): t_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "identify_redundancy"
#   }
# }
# ```
# Successfully extracted JSON for row 66
# --------------------------------------------------------
# Processing row 67 ...
# Raw text (last 200 chars): orrect_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "identify_error"
#   }
# }
# ```
# Successfully extracted JSON for row 67
# --------------------------------------------------------
# Processing row 68 ...
# Raw text (last 200 chars): "correct_solution": 1,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 0,
#     "next_action_category": "Generic",
#     "next_action_subcategory": "confirmation"
#   }
# }
# ```
# Successfully extracted JSON for row 68
# --------------------------------------------------------
# Processing row 69 ...
# Raw text (last 200 chars): lution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "elicit_initial_approach"
#   }
# }
# ```
# Successfully extracted JSON for row 69
# --------------------------------------------------------
# Processing row 70 ...
# Raw text (last 200 chars): solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_initial_setup"
#   }
# }
# ```
# Successfully extracted JSON for row 70
# --------------------------------------------------------
# Processing row 71 ...
# Raw text (last 200 chars): _solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "calculate_total_cost"
#   }
# }
# ```
# Successfully extracted JSON for row 71
# --------------------------------------------------------
# Processing row 72 ...
# Raw text (last 200 chars): solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "equation_simplification"
#   }
# }
# ```
# Successfully extracted JSON for row 72
# --------------------------------------------------------
# Processing row 73 ...
# Raw text (last 200 chars): ct_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "direct_instruction"
#   }
# }
# ```
# Successfully extracted JSON for row 73
# --------------------------------------------------------
# Processing row 74 ...
# Raw text (last 200 chars): 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "provide_step_by_step_instruction"
#   }
# }
# ```
# Successfully extracted JSON for row 74
# --------------------------------------------------------
# Processing row 75 ...
# Raw text (last 200 chars): rrect_solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "ask_about_units"
#   }
# }
# ```
# Successfully extracted JSON for row 75
# --------------------------------------------------------
# Processing row 76 ...
# Raw text (last 200 chars): olution": 1,
#     "problem_difficulty": 1
#   },
#   "action": {
#     "next_action_hint_strength": 0,
#     "next_action_category": "Generic",
#     "next_action_subcategory": "positive_reinforcement"
#   }
# }
# ```
# Successfully extracted JSON for row 76
# --------------------------------------------------------
# Processing row 77 ...
# Raw text (last 200 chars): olution": 0,
#     "problem_difficulty": 1
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_per_person_use"
#   }
# }
# ```
# Successfully extracted JSON for row 77
# --------------------------------------------------------
# Processing row 78 ...
# Raw text (last 200 chars): solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "clarify_meals_per_day"
#   }
# }
# ```
# Successfully extracted JSON for row 78
# --------------------------------------------------------
# Processing row 79 ...
# Raw text (last 200 chars): ,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "provide_correct_intermediate_step"
#   }
# }
# ```
# Successfully extracted JSON for row 79
# --------------------------------------------------------
# Processing row 80 ...
# Raw text (last 200 chars): _solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Focus",
#     "next_action_subcategory": "focus_on_initial_setup"
#   }
# }
# ```
# Successfully extracted JSON for row 80
# --------------------------------------------------------
# Processing row 81 ...
# Raw text (last 200 chars): solution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Telling",
#     "next_action_subcategory": "provide_solution_step"
#   }
# }
# ```
# Successfully extracted JSON for row 81
# --------------------------------------------------------
# Processing row 82 ...
# Raw text (last 200 chars): : 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 2,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "check_intermediate_calculation"
#   }
# }
# ```
# Successfully extracted JSON for row 82
# --------------------------------------------------------
# Processing row 83 ...
# Raw text (last 200 chars): ": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "identify_relevant_information"
#   }
# }
# ```
# Successfully extracted JSON for row 83
# --------------------------------------------------------
# Processing row 84 ...
# Raw text (last 200 chars): lution": 0,
#     "problem_difficulty": 2
#   },
#   "action": {
#     "next_action_hint_strength": 1,
#     "next_action_category": "Probing",
#     "next_action_subcategory": "reveal_student_thinking"
#   }
# }
# ```
# Successfully extracted JSON for row 84
# --------------------------------------------------------
# Processing row 85 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 334
#     331 try:
#     332     print(f"Processing row {i} ...")
# --> 334     response = client.chat(model='gemma3:27b', messages=[
#     335           {
#     336             'role': 'user',
#     337             "content": prompt.strip()
#     338           },
#     339         ])
#     341     raw_response = response['message']['content']
#     343     if i == 0:
#
# File /opt/anaconda3/lib/python3.12/site-packages/ollama/_client.py:333, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     289 def chat(
#     290   self,
#     291   model: str = '',
#    (...)
#     298   keep_alive: Optional[Union[float, str]] = None,
#     299 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     300   """
#     301   Create a chat response using the requested model.
#     302
#    (...)
#     331   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     332   """
# --> 333   return self._request(
#     334     ChatResponse,
#     335     'POST',
#     336     '/api/chat',
#     337     json=ChatRequest(
#     338       model=model,
#     339       messages=[message for message in _copy_messages(messages)],
#     340       tools=[tool for tool in _copy_tools(tools)],
#     341       stream=stream,
#     342       format=format,
#     343       options=options,
#     344       keep_alive=keep_alive,
#     345     ).model_dump(exclude_none=True),
#     346     stream=stream,
#     347   )
#
# File /opt/anaconda3/lib/python3.12/site-packages/ollama/_client.py:178, in Client._request(self, cls, stream, *args, **kwargs)
#     174         yield cls(**part)
#     176   return inner()
# --> 178 return cls(**self._request_raw(*args, **kwargs).json())
#
# File /opt/anaconda3/lib/python3.12/site-packages/ollama/_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     116 def _request_raw(self, *args, **kwargs):
#     117   try:
# --> 118     r = self._client.request(*args, **kwargs)
#     119     r.raise_for_status()
#     120     return r
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
