# %%
import random
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Normal
import matplotlib.pyplot as plt
import sys
import copy
# %matplotlib inline

# %%
# policy evaluation with Monte Carlo
def eval_policy(policy, eval_env, eval_episodes=10):
        avg_reward = 0.0
        for _ in range(eval_episodes):
            state, _ = eval_env.reset()
            done = False
            step = 0
            while not done:
                action = policy.select_action(np.array(state))
                state, reward, terminated, _, _ = eval_env.step(action)
                avg_reward += reward
                step += 1
                done = terminated
        avg_reward /= eval_episodes

        print("---------------------------------------")
        print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
        print("---------------------------------------")
        return avg_reward

# %%
# Replay buffer
class ReplayBuffer(object):
    def __init__(self, state_dim, action_dim, max_size=int(1e6)):
        self.max_size = max_size
        self.ptr = 0
        self.size = 0

        self.state = np.zeros((max_size, state_dim))
        self.action = np.zeros((max_size, action_dim))
        self.next_state = np.zeros((max_size, state_dim))
        self.reward = np.zeros((max_size, 1))
        self.not_done = np.zeros((max_size, 1))

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


    def add(self, state, action, next_state, reward, done):
        self.state[self.ptr] = state
        self.action[self.ptr] = action
        self.next_state[self.ptr] = next_state
        self.reward[self.ptr] = reward
        self.not_done[self.ptr] = 1. - done

        self.ptr = (self.ptr + 1) % self.max_size
        self.size = min(self.size + 1, self.max_size)


    def sample(self, batch_size):
        ind = np.random.randint(0, self.size, size=batch_size)

        return (
            torch.FloatTensor(self.state[ind]).to(self.device),
            torch.FloatTensor(self.action[ind]).to(self.device),
            torch.FloatTensor(self.next_state[ind]).to(self.device),
            torch.FloatTensor(self.reward[ind]).to(self.device),
            torch.FloatTensor(self.not_done[ind]).to(self.device)
        )

# %%
import sys
sys.path.append('../models/simulator_and_related_models/')
from env import simulator

# %%
# simulator()

# %%
# Implementation of Twin Delayed Deep Deterministic Policy Gradients (TD3)
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

device = torch.device("cpu")

# if torch.cuda.is_available():
#     device = torch.device("cuda")
# elif torch.backends.mps.is_available():
#     device = torch.device("mps")

print(device)

class Actor_TD3(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor_TD3, self).__init__()

        self.l1 = nn.Linear(state_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, action_dim)

        self.max_action = max_action


    def forward(self, state):
        a = F.relu(self.l1(state))
        a = F.relu(self.l2(a))
        return self.max_action * torch.tanh(self.l3(a))


class Critic_TD3(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic_TD3, self).__init__()

        # Q1 architecture
        self.l1 = nn.Linear(state_dim + action_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 1)

        # Q2 architecture
        self.l4 = nn.Linear(state_dim + action_dim, 256)
        self.l5 = nn.Linear(256, 256)
        self.l6 = nn.Linear(256, 1)


    def forward(self, state, action):
        sa = torch.cat([state, action], 1)
        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)

        q2 = F.relu(self.l4(sa))
        q2 = F.relu(self.l5(q2))
        q2 = self.l6(q2)
        return q1, q2


    def Q1(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)
        return q1


class TD3(object):
    def __init__(
        self,
        state_dim,
        action_dim,
        max_action,
        discount=0.99,
        tau=0.005,
        policy_noise=0.2,
        noise_clip=0.5,
        policy_freq=2
    ):

        self.actor = Actor_TD3(state_dim, action_dim, max_action).to(device)
        self.actor_target = copy.deepcopy(self.actor)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=3e-4)

        self.critic = Critic_TD3(state_dim, action_dim).to(device)
        self.critic_target = copy.deepcopy(self.critic)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=3e-4)

        self.max_action = max_action
        self.discount = discount
        self.tau = tau
        self.policy_noise = policy_noise
        self.noise_clip = noise_clip
        self.policy_freq = policy_freq
        self.total_it = 0


    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()


    def train(self, replay_buffer, batch_size=256):
        self.total_it += 1

        # print(self.total_it)
        
        # Sample replay buffer
        state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

        with torch.no_grad():
            # Select action according to policy and add clipped noise
            noise = (
                torch.randn_like(action) * self.policy_noise
            ).clamp(-self.noise_clip, self.noise_clip)

            next_action = (
                self.actor_target(next_state) + noise
            ).clamp(-self.max_action, self.max_action)

            # Compute the target Q value
            target_Q1, target_Q2 = self.critic_target(next_state, next_action)

            # Compute the target_Q here
            target_Q = torch.min(target_Q1, target_Q2)
            target_Q = reward + not_done * self.discount * target_Q

        # Get current Q estimates
        current_Q1, current_Q2 = self.critic(state, action)

        # Compute critic loss
        critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

        # Optimize the critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Delayed policy updates
        if self.total_it % self.policy_freq == 0:

            # Compute actor loss
            # pi = self.actor(state)
            # actor_loss = -self.critic.Q1(state, pi).mean() + F.mse_loss(pi, action)
            actor_loss = -self.critic.Q1(state, self.actor(state)).mean()

            # Optimize the actor
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            # Update the frozen target models
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)
# Out:
# cpu

# %%
def init_flags():

        flags = {
                "env": "Pendulum-v1",
                "seed":0,
                "start_timesteps": 2e4,
                "max_timesteps": 5e4,
                "expl_noise": 0.01,
                "batch_size": 256,
                "discount":0.99,
                "tau": 0.005,
                "policy_noise": 0.05,
                "noise_clip":0.5,
                "policy_freq": 2,
                "save_model": "store_true"
        }

        return flags

def main(policy_name = 'TD3'):

        args = init_flags()
        
        def reward(self, penalty, action):
            extra = 0
            if self.done == 1 and self.correct_solution == 0:
                extra = -8
            if action == 2:
                penalty = -5
            return self.prob_count * 13 + self.listen_to_feedback_count * 10 + extra + penalty + self.convo_turn + self.progress_delta
        
        env = simulator(reward)

        env.reset()
        torch.manual_seed(args["seed"])
        np.random.seed(args["seed"])

        state_dim = 7
        action_dim = 1
        max_action = 3
        kwargs = {
                "state_dim": state_dim,
                "action_dim": action_dim,
                "max_action": max_action,
                "discount": args["discount"],
                "tau": args["tau"],}
        if policy_name == "TD3":
                # Target policy smoothing is scaled wrt the action scale
                kwargs["policy_noise"] = args["policy_noise"] * max_action
                kwargs["noise_clip"] = args["noise_clip"] * max_action
                kwargs["policy_freq"] = args["policy_freq"]
                policy = TD3(**kwargs)
        elif policy_name == "SAC":
                policy = SAC(**kwargs)

        replay_buffer = ReplayBuffer(state_dim, action_dim)
        evaluations = [eval_policy(policy, env)]
        state, _ = env.reset()
        done = False
        episode_reward = 0
        episode_timesteps = 0
        episode_num = 0

        for t in range(int(args["max_timesteps"])):
            episode_timesteps += 1

            # Select action randomly or according to policy
            if t < args["start_timesteps"]:
                action = np.random.choice(env.action_space)
            else:
                action = (
                    policy.select_action(np.array(state))
                    + np.random.normal(0, max_action * args["expl_noise"], size=action_dim)
                ).clip(-max_action, max_action)

            # Perform action
            next_state, reward, terminated, _, _ = env.step(action)
            done = terminated
            done_bool = float(done) if episode_timesteps < env._max_episode_steps else 0

            # Store data in replay buffer
            replay_buffer.add(state, action, next_state, reward, done_bool)

            state = next_state
            episode_reward += reward

            # Train agent after collecting sufficient data
            if t >= args["start_timesteps"]:
                policy.train(replay_buffer, args["batch_size"])

            if episode_num % 10 == 0:
                # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
                    print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")

            if done:
                evaluations.append(episode_reward)

                # Reset environment
                state, _ = env.reset()
                done = False
                episode_reward = 0
                episode_timesteps = 0
                episode_num += 1

        return policy,evaluations

# %%
policy, evaluation_td3 = main(policy_name = 'TD3')
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(evaluation_td3)
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Pendulum with TD3')
plt.grid()
plt.show()
# Out:
# ---------------------------------------
# Evaluation over 10 episodes: 33.400
# ---------------------------------------
# Total T: 1 Episode Num: 1 Episode T: 1 Reward: 102.000
# Total T: 15 Episode Num: 11 Episode T: 1 Reward: 3.000
# Total T: 27 Episode Num: 21 Episode T: 1 Reward: 126.000
# Total T: 37 Episode Num: 31 Episode T: 1 Reward: 11.000
# Total T: 38 Episode Num: 31 Episode T: 2 Reward: 134.000
# Total T: 54 Episode Num: 41 Episode T: 1 Reward: 3.000
# Total T: 67 Episode Num: 51 Episode T: 1 Reward: 17.000
# Total T: 68 Episode Num: 51 Episode T: 2 Reward: 145.000
# Total T: 80 Episode Num: 61 Episode T: 1 Reward: 132.000
# Total T: 91 Episode Num: 71 Episode T: 1 Reward: 49.000
# Total T: 104 Episode Num: 81 Episode T: 1 Reward: 126.000
# Total T: 118 Episode Num: 91 Episode T: 1 Reward: 132.000
# Total T: 131 Episode Num: 101 Episode T: 1 Reward: 132.000
# Total T: 142 Episode Num: 111 Episode T: 1 Reward: 49.000
# Total T: 155 Episode Num: 121 Episode T: 1 Reward: 126.000
# Total T: 166 Episode Num: 131 Episode T: 1 Reward: 36.000
# Total T: 167 Episode Num: 131 Episode T: 2 Reward: 172.000
# Total T: 177 Episode Num: 141 Episode T: 1 Reward: 12.000
# Total T: 178 Episode Num: 141 Episode T: 2 Reward: 17.000
# Total T: 189 Episode Num: 151 Episode T: 1 Reward: 9.000
# Total T: 202 Episode Num: 161 Episode T: 1 Reward: 126.000
# Total T: 217 Episode Num: 171 Episode T: 1 Reward: 132.000
# Total T: 229 Episode Num: 181 Episode T: 1 Reward: 112.000
# Total T: 241 Episode Num: 191 Episode T: 1 Reward: 122.000
# Total T: 253 Episode Num: 201 Episode T: 1 Reward: 126.000
# Total T: 265 Episode Num: 211 Episode T: 1 Reward: 2.000
# Total T: 266 Episode Num: 211 Episode T: 2 Reward: 6.000
# Total T: 279 Episode Num: 221 Episode T: 1 Reward: 112.000
# Total T: 293 Episode Num: 231 Episode T: 1 Reward: 112.000
# Total T: 303 Episode Num: 241 Episode T: 1 Reward: 112.000
# Total T: 315 Episode Num: 251 Episode T: 1 Reward: 1.000
# Total T: 316 Episode Num: 251 Episode T: 2 Reward: 4.000
# Total T: 317 Episode Num: 251 Episode T: 3 Reward: 42.000
# Total T: 318 Episode Num: 251 Episode T: 4 Reward: 190.000
# Total T: 331 Episode Num: 261 Episode T: 1 Reward: 126.000
# Total T: 343 Episode Num: 271 Episode T: 1 Reward: 126.000
# Total T: 355 Episode Num: 281 Episode T: 1 Reward: 11.000
# Total T: 356 Episode Num: 281 Episode T: 2 Reward: 15.000
# Total T: 368 Episode Num: 291 Episode T: 1 Reward: 122.000
# Total T: 378 Episode Num: 301 Episode T: 1 Reward: 49.000
# Total T: 391 Episode Num: 311 Episode T: 1 Reward: -7.000
# Total T: 403 Episode Num: 321 Episode T: 1 Reward: -7.000
# Total T: 414 Episode Num: 331 Episode T: 1 Reward: 132.000
# Total T: 427 Episode Num: 341 Episode T: 1 Reward: -7.000
# Total T: 439 Episode Num: 351 Episode T: 1 Reward: -7.000
# Total T: 449 Episode Num: 361 Episode T: 1 Reward: 3.000
# Total T: 459 Episode Num: 371 Episode T: 1 Reward: 132.000
# Total T: 469 Episode Num: 381 Episode T: 1 Reward: 126.000
# Total T: 482 Episode Num: 391 Episode T: 1 Reward: 132.000
# Total T: 494 Episode Num: 401 Episode T: 1 Reward: 132.000
# Total T: 508 Episode Num: 411 Episode T: 1 Reward: 126.000
# Total T: 521 Episode Num: 421 Episode T: 1 Reward: 3.000
# Total T: 534 Episode Num: 431 Episode T: 1 Reward: 9.000
# Total T: 547 Episode Num: 441 Episode T: 1 Reward: 11.000
# Total T: 548 Episode Num: 441 Episode T: 2 Reward: 138.000
# Total T: 565 Episode Num: 451 Episode T: 1 Reward: 132.000
# Total T: 577 Episode Num: 461 Episode T: 1 Reward: 1.000
# Total T: 578 Episode Num: 461 Episode T: 2 Reward: 134.000
# Total T: 589 Episode Num: 471 Episode T: 1 Reward: 36.000
# Total T: 590 Episode Num: 471 Episode T: 2 Reward: 182.000
# Total T: 604 Episode Num: 481 Episode T: 1 Reward: 11.000
# Total T: 605 Episode Num: 481 Episode T: 2 Reward: 148.000
# Total T: 620 Episode Num: 491 Episode T: 1 Reward: 126.000
# Total T: 634 Episode Num: 501 Episode T: 1 Reward: 49.000
# Total T: 648 Episode Num: 511 Episode T: 1 Reward: 11.000
# Total T: 649 Episode Num: 511 Episode T: 2 Reward: 25.000
# Total T: 660 Episode Num: 521 Episode T: 1 Reward: 112.000
# Total T: 676 Episode Num: 531 Episode T: 1 Reward: 132.000
# Total T: 690 Episode Num: 541 Episode T: 1 Reward: 132.000
# Total T: 704 Episode Num: 551 Episode T: 1 Reward: 132.000
# Total T: 716 Episode Num: 561 Episode T: 1 Reward: 132.000
# Total T: 729 Episode Num: 571 Episode T: 1 Reward: 2.000
# Total T: 730 Episode Num: 571 Episode T: 2 Reward: 125.000
# Total T: 741 Episode Num: 581 Episode T: 1 Reward: 11.000
# Total T: 742 Episode Num: 581 Episode T: 2 Reward: 39.000
# Total T: 743 Episode Num: 581 Episode T: 3 Reward: 188.000
# Total T: 757 Episode Num: 591 Episode T: 1 Reward: 126.000
# Total T: 772 Episode Num: 601 Episode T: 1 Reward: 3.000
# Total T: 784 Episode Num: 611 Episode T: 1 Reward: 12.000
# Total T: 785 Episode Num: 611 Episode T: 2 Reward: 125.000
# Total T: 797 Episode Num: 621 Episode T: 1 Reward: 3.000
# Total T: 810 Episode Num: 631 Episode T: 1 Reward: -7.000
# Total T: 822 Episode Num: 641 Episode T: 1 Reward: 2.000
# Total T: 823 Episode Num: 641 Episode T: 2 Reward: 135.000
# Total T: 836 Episode Num: 651 Episode T: 1 Reward: 112.000
# Total T: 850 Episode Num: 661 Episode T: 1 Reward: 116.000
# Total T: 863 Episode Num: 671 Episode T: 1 Reward: 116.000
# Total T: 873 Episode Num: 681 Episode T: 1 Reward: 132.000
# Total T: 883 Episode Num: 691 Episode T: 1 Reward: 112.000
# Total T: 894 Episode Num: 701 Episode T: 1 Reward: 132.000
# Total T: 907 Episode Num: 711 Episode T: 1 Reward: 132.000
# Total T: 917 Episode Num: 721 Episode T: 1 Reward: 112.000
# Total T: 932 Episode Num: 731 Episode T: 1 Reward: 3.000
# Total T: 950 Episode Num: 741 Episode T: 1 Reward: 102.000
# Total T: 960 Episode Num: 751 Episode T: 1 Reward: 132.000
# Total T: 975 Episode Num: 761 Episode T: 1 Reward: 122.000
# Total T: 986 Episode Num: 771 Episode T: 1 Reward: 1.000
# Total T: 987 Episode Num: 771 Episode T: 2 Reward: 134.000
# Total T: 999 Episode Num: 781 Episode T: 1 Reward: 112.000
# Total T: 1012 Episode Num: 791 Episode T: 1 Reward: 4.000
# Total T: 1025 Episode Num: 801 Episode T: 1 Reward: 126.000
# Total T: 1041 Episode Num: 811 Episode T: 1 Reward: 26.000
# Total T: 1042 Episode Num: 811 Episode T: 2 Reward: 155.000
# Total T: 1053 Episode Num: 821 Episode T: 1 Reward: 36.000
# Total T: 1054 Episode Num: 821 Episode T: 2 Reward: 53.000
# Total T: 1065 Episode Num: 831 Episode T: 1 Reward: -7.000
# Total T: 1078 Episode Num: 841 Episode T: 1 Reward: 112.000
# Total T: 1093 Episode Num: 851 Episode T: 1 Reward: 126.000
# Total T: 1106 Episode Num: 861 Episode T: 1 Reward: 132.000
# Total T: 1120 Episode Num: 871 Episode T: 1 Reward: 12.000
# Total T: 1121 Episode Num: 871 Episode T: 2 Reward: 149.000
# Total T: 1132 Episode Num: 881 Episode T: 1 Reward: -7.000
# Total T: 1142 Episode Num: 891 Episode T: 1 Reward: 112.000
# Total T: 1157 Episode Num: 901 Episode T: 1 Reward: 1.000
# Total T: 1158 Episode Num: 901 Episode T: 2 Reward: 6.000
# Total T: 1168 Episode Num: 911 Episode T: 1 Reward: 112.000
# Total T: 1180 Episode Num: 921 Episode T: 1 Reward: 126.000
# Total T: 1194 Episode Num: 931 Episode T: 1 Reward: 4.000
# Total T: 1204 Episode Num: 941 Episode T: 1 Reward: 132.000
# Total T: 1217 Episode Num: 951 Episode T: 1 Reward: 102.000
# Total T: 1231 Episode Num: 961 Episode T: 1 Reward: 12.000
# Total T: 1232 Episode Num: 961 Episode T: 2 Reward: 125.000
# Total T: 1245 Episode Num: 971 Episode T: 1 Reward: 11.000
# Total T: 1246 Episode Num: 971 Episode T: 2 Reward: 21.000
# Total T: 1257 Episode Num: 981 Episode T: 1 Reward: 132.000
# Total T: 1274 Episode Num: 991 Episode T: 1 Reward: 132.000
# Total T: 1287 Episode Num: 1001 Episode T: 1 Reward: 132.000
# Total T: 1300 Episode Num: 1011 Episode T: 1 Reward: 7.000
# Total T: 1301 Episode Num: 1011 Episode T: 2 Reward: 129.000
# Total T: 1315 Episode Num: 1021 Episode T: 1 Reward: 126.000
# Total T: 1325 Episode Num: 1031 Episode T: 1 Reward: 3.000
# Total T: 1340 Episode Num: 1041 Episode T: 1 Reward: 122.000
# Total T: 1354 Episode Num: 1051 Episode T: 1 Reward: 132.000
# Total T: 1366 Episode Num: 1061 Episode T: 1 Reward: 112.000
# Total T: 1379 Episode Num: 1071 Episode T: 1 Reward: 11.000
# Total T: 1380 Episode Num: 1071 Episode T: 2 Reward: 154.000
# Total T: 1392 Episode Num: 1081 Episode T: 1 Reward: 132.000
# Total T: 1404 Episode Num: 1091 Episode T: 1 Reward: 126.000
# Total T: 1417 Episode Num: 1101 Episode T: 1 Reward: 102.000
# Total T: 1434 Episode Num: 1111 Episode T: 1 Reward: 132.000
# Total T: 1446 Episode Num: 1121 Episode T: 1 Reward: -7.000
# Total T: 1460 Episode Num: 1131 Episode T: 1 Reward: 126.000
# Total T: 1471 Episode Num: 1141 Episode T: 1 Reward: 126.000
# Total T: 1485 Episode Num: 1151 Episode T: 1 Reward: 112.000
# Total T: 1496 Episode Num: 1161 Episode T: 1 Reward: 132.000
# Total T: 1508 Episode Num: 1171 Episode T: 1 Reward: 132.000
# Total T: 1521 Episode Num: 1181 Episode T: 1 Reward: 102.000
# Total T: 1534 Episode Num: 1191 Episode T: 1 Reward: 126.000
# Total T: 1547 Episode Num: 1201 Episode T: 1 Reward: 126.000
# Total T: 1561 Episode Num: 1211 Episode T: 1 Reward: 112.000
# Total T: 1573 Episode Num: 1221 Episode T: 1 Reward: 132.000
# Total T: 1586 Episode Num: 1231 Episode T: 1 Reward: 132.000
# Total T: 1597 Episode Num: 1241 Episode T: 1 Reward: 132.000
# Total T: 1612 Episode Num: 1251 Episode T: 1 Reward: 102.000
# Total T: 1625 Episode Num: 1261 Episode T: 1 Reward: 132.000
# Total T: 1638 Episode Num: 1271 Episode T: 1 Reward: 3.000
# Total T: 1651 Episode Num: 1281 Episode T: 1 Reward: 132.000
# Total T: 1664 Episode Num: 1291 Episode T: 1 Reward: 126.000
# Total T: 1678 Episode Num: 1301 Episode T: 1 Reward: 102.000
# Total T: 1689 Episode Num: 1311 Episode T: 1 Reward: 12.000
# Total T: 1690 Episode Num: 1311 Episode T: 2 Reward: 17.000
# Total T: 1706 Episode Num: 1321 Episode T: 1 Reward: 11.000
# Total T: 1707 Episode Num: 1321 Episode T: 2 Reward: 154.000
# Total T: 1721 Episode Num: 1331 Episode T: 1 Reward: 49.000
# Total T: 1732 Episode Num: 1341 Episode T: 1 Reward: 132.000
# Total T: 1745 Episode Num: 1351 Episode T: 1 Reward: 132.000
# Total T: 1756 Episode Num: 1361 Episode T: 1 Reward: 132.000
# Total T: 1767 Episode Num: 1371 Episode T: 1 Reward: 132.000
# Total T: 1779 Episode Num: 1381 Episode T: 1 Reward: -6.000
# Total T: 1789 Episode Num: 1391 Episode T: 1 Reward: 1.000
# Total T: 1790 Episode Num: 1391 Episode T: 2 Reward: 20.000
# Total T: 1806 Episode Num: 1401 Episode T: 1 Reward: 102.000
# Total T: 1816 Episode Num: 1411 Episode T: 1 Reward: 132.000
# Total T: 1827 Episode Num: 1421 Episode T: 1 Reward: 132.000
# Total T: 1841 Episode Num: 1431 Episode T: 1 Reward: 7.000
# Total T: 1842 Episode Num: 1431 Episode T: 2 Reward: 135.000
# Total T: 1854 Episode Num: 1441 Episode T: 1 Reward: 102.000
# Total T: 1866 Episode Num: 1451 Episode T: 1 Reward: 11.000
# Total T: 1867 Episode Num: 1451 Episode T: 2 Reward: 148.000
# Total T: 1882 Episode Num: 1461 Episode T: 1 Reward: 11.000
# Total T: 1883 Episode Num: 1461 Episode T: 2 Reward: 148.000
# Total T: 1894 Episode Num: 1471 Episode T: 1 Reward: 11.000
# Total T: 1895 Episode Num: 1471 Episode T: 2 Reward: 154.000
# Total T: 1906 Episode Num: 1481 Episode T: 1 Reward: 112.000
# Total T: 1917 Episode Num: 1491 Episode T: 1 Reward: -7.000
# Total T: 1928 Episode Num: 1501 Episode T: 1 Reward: 102.000
# Total T: 1939 Episode Num: 1511 Episode T: 1 Reward: 132.000
# Total T: 1952 Episode Num: 1521 Episode T: 1 Reward: 126.000
# Total T: 1963 Episode Num: 1531 Episode T: 1 Reward: 3.000
# Total T: 1973 Episode Num: 1541 Episode T: 1 Reward: 11.000
# Total T: 1974 Episode Num: 1541 Episode T: 2 Reward: 71.000
# Total T: 1985 Episode Num: 1551 Episode T: 1 Reward: 11.000
# Total T: 1986 Episode Num: 1551 Episode T: 2 Reward: 71.000
# Total T: 2001 Episode Num: 1561 Episode T: 1 Reward: 126.000
# Total T: 2014 Episode Num: 1571 Episode T: 1 Reward: 112.000
# Total T: 2026 Episode Num: 1581 Episode T: 1 Reward: 3.000
# Total T: 2038 Episode Num: 1591 Episode T: 1 Reward: 126.000
# Total T: 2050 Episode Num: 1601 Episode T: 1 Reward: 1.000
# Total T: 2051 Episode Num: 1601 Episode T: 2 Reward: -5.000
# Total T: 2063 Episode Num: 1611 Episode T: 1 Reward: 102.000
# Total T: 2077 Episode Num: 1621 Episode T: 1 Reward: 112.000
# Total T: 2090 Episode Num: 1631 Episode T: 1 Reward: 132.000
# Total T: 2101 Episode Num: 1641 Episode T: 1 Reward: 126.000
# Total T: 2113 Episode Num: 1651 Episode T: 1 Reward: 36.000
# Total T: 2114 Episode Num: 1651 Episode T: 2 Reward: 182.000
# Total T: 2129 Episode Num: 1661 Episode T: 1 Reward: 126.000
# Total T: 2141 Episode Num: 1671 Episode T: 1 Reward: -1.000
# Total T: 2153 Episode Num: 1681 Episode T: 1 Reward: 11.000
# Total T: 2154 Episode Num: 1681 Episode T: 2 Reward: 124.000
# Total T: 2167 Episode Num: 1691 Episode T: 1 Reward: 132.000
# Total T: 2178 Episode Num: 1701 Episode T: 1 Reward: 132.000
# Total T: 2190 Episode Num: 1711 Episode T: 1 Reward: -7.000
# Total T: 2203 Episode Num: 1721 Episode T: 1 Reward: 112.000
# Total T: 2215 Episode Num: 1731 Episode T: 1 Reward: -6.000
# Total T: 2230 Episode Num: 1741 Episode T: 1 Reward: 112.000
# Total T: 2244 Episode Num: 1751 Episode T: 1 Reward: 102.000
# Total T: 2256 Episode Num: 1761 Episode T: 1 Reward: 1.000
# Total T: 2257 Episode Num: 1761 Episode T: 2 Reward: 104.000
# Total T: 2268 Episode Num: 1771 Episode T: 1 Reward: 1.000
# Total T: 2269 Episode Num: 1771 Episode T: 2 Reward: -5.000
# Total T: 2282 Episode Num: 1781 Episode T: 1 Reward: 36.000
# Total T: 2283 Episode Num: 1781 Episode T: 2 Reward: 87.000
# Total T: 2295 Episode Num: 1791 Episode T: 1 Reward: 36.000
# Total T: 2296 Episode Num: 1791 Episode T: 2 Reward: 172.000
# Total T: 2310 Episode Num: 1801 Episode T: 1 Reward: -7.000
# Total T: 2322 Episode Num: 1811 Episode T: 1 Reward: 4.000
# Total T: 2335 Episode Num: 1821 Episode T: 1 Reward: 1.000
# Total T: 2336 Episode Num: 1821 Episode T: 2 Reward: 5.000
# Total T: 2346 Episode Num: 1831 Episode T: 1 Reward: 3.000
# Total T: 2358 Episode Num: 1841 Episode T: 1 Reward: 116.000
# Total T: 2369 Episode Num: 1851 Episode T: 1 Reward: -7.000
# Total T: 2380 Episode Num: 1861 Episode T: 1 Reward: -6.000
# Total T: 2394 Episode Num: 1871 Episode T: 1 Reward: 132.000
# Total T: 2406 Episode Num: 1881 Episode T: 1 Reward: 116.000
# Total T: 2418 Episode Num: 1891 Episode T: 1 Reward: 132.000
# Total T: 2432 Episode Num: 1901 Episode T: 1 Reward: 132.000
# Total T: 2450 Episode Num: 1911 Episode T: 1 Reward: 126.000
# Total T: 2463 Episode Num: 1921 Episode T: 1 Reward: 126.000
# Total T: 2475 Episode Num: 1931 Episode T: 1 Reward: 116.000
# Total T: 2489 Episode Num: 1941 Episode T: 1 Reward: 112.000
# Total T: 2506 Episode Num: 1951 Episode T: 1 Reward: 132.000
# Total T: 2517 Episode Num: 1961 Episode T: 1 Reward: -1.000
# Total T: 2529 Episode Num: 1971 Episode T: 1 Reward: 132.000
# Total T: 2539 Episode Num: 1981 Episode T: 1 Reward: 126.000
# Total T: 2555 Episode Num: 1991 Episode T: 1 Reward: 132.000
# Total T: 2569 Episode Num: 2001 Episode T: 1 Reward: 3.000
# Total T: 2580 Episode Num: 2011 Episode T: 1 Reward: -7.000
# Total T: 2591 Episode Num: 2021 Episode T: 1 Reward: 122.000
# Total T: 2605 Episode Num: 2031 Episode T: 1 Reward: -7.000
# Total T: 2619 Episode Num: 2041 Episode T: 1 Reward: 132.000
# Total T: 2632 Episode Num: 2051 Episode T: 1 Reward: 132.000
# Total T: 2643 Episode Num: 2061 Episode T: 1 Reward: 132.000
# Total T: 2656 Episode Num: 2071 Episode T: 1 Reward: 12.000
# Total T: 2657 Episode Num: 2071 Episode T: 2 Reward: 16.000
# Total T: 2668 Episode Num: 2081 Episode T: 1 Reward: 126.000
# Total T: 2678 Episode Num: 2091 Episode T: 1 Reward: 126.000
# Total T: 2692 Episode Num: 2101 Episode T: 1 Reward: 12.000
# Total T: 2693 Episode Num: 2101 Episode T: 2 Reward: 125.000
# Total T: 2703 Episode Num: 2111 Episode T: 1 Reward: 132.000
# Total T: 2717 Episode Num: 2121 Episode T: 1 Reward: 11.000
# Total T: 2718 Episode Num: 2121 Episode T: 2 Reward: 124.000
# Total T: 2731 Episode Num: 2131 Episode T: 1 Reward: 132.000
# Total T: 2743 Episode Num: 2141 Episode T: 1 Reward: 112.000
# Total T: 2755 Episode Num: 2151 Episode T: 1 Reward: 11.000
# Total T: 2756 Episode Num: 2151 Episode T: 2 Reward: 15.000
# Total T: 2766 Episode Num: 2161 Episode T: 1 Reward: 126.000
# Total T: 2776 Episode Num: 2171 Episode T: 1 Reward: 1.000
# Total T: 2777 Episode Num: 2171 Episode T: 2 Reward: 114.000
# Total T: 2788 Episode Num: 2181 Episode T: 1 Reward: 49.000
# Total T: 2801 Episode Num: 2191 Episode T: 1 Reward: 11.000
# Total T: 2802 Episode Num: 2191 Episode T: 2 Reward: 26.000
# Total T: 2816 Episode Num: 2201 Episode T: 1 Reward: 132.000
# Total T: 2831 Episode Num: 2211 Episode T: 1 Reward: 116.000
# Total T: 2844 Episode Num: 2221 Episode T: 1 Reward: 112.000
# Total T: 2857 Episode Num: 2231 Episode T: 1 Reward: -1.000
# Total T: 2870 Episode Num: 2241 Episode T: 1 Reward: 11.000
# Total T: 2871 Episode Num: 2241 Episode T: 2 Reward: 154.000
# Total T: 2883 Episode Num: 2251 Episode T: 1 Reward: -7.000
# Total T: 2896 Episode Num: 2261 Episode T: 1 Reward: 112.000
# Total T: 2909 Episode Num: 2271 Episode T: 1 Reward: 126.000
# Total T: 2922 Episode Num: 2281 Episode T: 1 Reward: 102.000
# Total T: 2933 Episode Num: 2291 Episode T: 1 Reward: 11.000
# Total T: 2934 Episode Num: 2291 Episode T: 2 Reward: 124.000
# Total T: 2945 Episode Num: 2301 Episode T: 1 Reward: 132.000
# Total T: 2955 Episode Num: 2311 Episode T: 1 Reward: 3.000
# Total T: 2967 Episode Num: 2321 Episode T: 1 Reward: 132.000
# Total T: 2977 Episode Num: 2331 Episode T: 1 Reward: 132.000
# Total T: 2988 Episode Num: 2341 Episode T: 1 Reward: -6.000
# Total T: 3000 Episode Num: 2351 Episode T: 1 Reward: 112.000
# Total T: 3013 Episode Num: 2361 Episode T: 1 Reward: 126.000
# Total T: 3025 Episode Num: 2371 Episode T: 1 Reward: 7.000
# Total T: 3026 Episode Num: 2371 Episode T: 2 Reward: 135.000
# Total T: 3039 Episode Num: 2381 Episode T: 1 Reward: 7.000
# Total T: 3040 Episode Num: 2381 Episode T: 2 Reward: 57.000
# Total T: 3052 Episode Num: 2391 Episode T: 1 Reward: 126.000
# Total T: 3062 Episode Num: 2401 Episode T: 1 Reward: 132.000
# Total T: 3075 Episode Num: 2411 Episode T: 1 Reward: 7.000
# Total T: 3076 Episode Num: 2411 Episode T: 2 Reward: 119.000
# Total T: 3088 Episode Num: 2421 Episode T: 1 Reward: 126.000
# Total T: 3100 Episode Num: 2431 Episode T: 1 Reward: 126.000
# Total T: 3112 Episode Num: 2441 Episode T: 1 Reward: 12.000
# Total T: 3113 Episode Num: 2441 Episode T: 2 Reward: 145.000
# Total T: 3125 Episode Num: 2451 Episode T: 1 Reward: 1.000
# Total T: 3126 Episode Num: 2451 Episode T: 2 Reward: 104.000
# Total T: 3143 Episode Num: 2461 Episode T: 1 Reward: 132.000
# Total T: 3153 Episode Num: 2471 Episode T: 1 Reward: 126.000
# Total T: 3166 Episode Num: 2481 Episode T: 1 Reward: 126.000
# Total T: 3177 Episode Num: 2491 Episode T: 1 Reward: 1.000
# Total T: 3178 Episode Num: 2491 Episode T: 2 Reward: 128.000
# Total T: 3189 Episode Num: 2501 Episode T: 1 Reward: 122.000
# Total T: 3201 Episode Num: 2511 Episode T: 1 Reward: 1.000
# Total T: 3202 Episode Num: 2511 Episode T: 2 Reward: 134.000
# Total T: 3212 Episode Num: 2521 Episode T: 1 Reward: 132.000
# Total T: 3224 Episode Num: 2531 Episode T: 1 Reward: -6.000
# Total T: 3235 Episode Num: 2541 Episode T: 1 Reward: 132.000
# Total T: 3245 Episode Num: 2551 Episode T: 1 Reward: 102.000
# Total T: 3258 Episode Num: 2561 Episode T: 1 Reward: 26.000
# Total T: 3259 Episode Num: 2561 Episode T: 2 Reward: 155.000
# Total T: 3271 Episode Num: 2571 Episode T: 1 Reward: -7.000
# Total T: 3285 Episode Num: 2581 Episode T: 1 Reward: 31.000
# Total T: 3286 Episode Num: 2581 Episode T: 2 Reward: 182.000
# Total T: 3302 Episode Num: 2591 Episode T: 1 Reward: 7.000
# Total T: 3303 Episode Num: 2591 Episode T: 2 Reward: 125.000
# Total T: 3317 Episode Num: 2601 Episode T: 1 Reward: 126.000
# Total T: 3329 Episode Num: 2611 Episode T: 1 Reward: 126.000
# Total T: 3341 Episode Num: 2621 Episode T: 1 Reward: 36.000
# Total T: 3342 Episode Num: 2621 Episode T: 2 Reward: 61.000
# Total T: 3343 Episode Num: 2621 Episode T: 3 Reward: 97.000
# Total T: 3344 Episode Num: 2621 Episode T: 4 Reward: 238.000
# Total T: 3359 Episode Num: 2631 Episode T: 1 Reward: 112.000
# Total T: 3373 Episode Num: 2641 Episode T: 1 Reward: 3.000
# Total T: 3383 Episode Num: 2651 Episode T: 1 Reward: 126.000
# Total T: 3394 Episode Num: 2661 Episode T: 1 Reward: 11.000
# Total T: 3395 Episode Num: 2661 Episode T: 2 Reward: 15.000
# Total T: 3412 Episode Num: 2671 Episode T: 1 Reward: 17.000
# Total T: 3413 Episode Num: 2671 Episode T: 2 Reward: 30.000
# Total T: 3414 Episode Num: 2671 Episode T: 3 Reward: 159.000
# Total T: 3426 Episode Num: 2681 Episode T: 1 Reward: 132.000
# Total T: 3441 Episode Num: 2691 Episode T: 1 Reward: 4.000
# Total T: 3454 Episode Num: 2701 Episode T: 1 Reward: 28.000
# Total T: 3467 Episode Num: 2711 Episode T: 1 Reward: -7.000
# Total T: 3483 Episode Num: 2721 Episode T: 1 Reward: 126.000
# Total T: 3498 Episode Num: 2731 Episode T: 1 Reward: 112.000
# Total T: 3513 Episode Num: 2741 Episode T: 1 Reward: 132.000
# Total T: 3529 Episode Num: 2751 Episode T: 1 Reward: 3.000
# Total T: 3541 Episode Num: 2761 Episode T: 1 Reward: 1.000
# Total T: 3542 Episode Num: 2761 Episode T: 2 Reward: 114.000
# Total T: 3554 Episode Num: 2771 Episode T: 1 Reward: 126.000
# Total T: 3567 Episode Num: 2781 Episode T: 1 Reward: 132.000
# Total T: 3579 Episode Num: 2791 Episode T: 1 Reward: 126.000
# Total T: 3590 Episode Num: 2801 Episode T: 1 Reward: 11.000
# Total T: 3591 Episode Num: 2801 Episode T: 2 Reward: 154.000
# Total T: 3605 Episode Num: 2811 Episode T: 1 Reward: 1.000
# Total T: 3606 Episode Num: 2811 Episode T: 2 Reward: 38.000
# Total T: 3607 Episode Num: 2811 Episode T: 3 Reward: 168.000
# Total T: 3620 Episode Num: 2821 Episode T: 1 Reward: 116.000
# Total T: 3633 Episode Num: 2831 Episode T: 1 Reward: 49.000
# Total T: 3648 Episode Num: 2841 Episode T: 1 Reward: 132.000
# Total T: 3658 Episode Num: 2851 Episode T: 1 Reward: 9.000
# Total T: 3672 Episode Num: 2861 Episode T: 1 Reward: 17.000
# Total T: 3673 Episode Num: 2861 Episode T: 2 Reward: 155.000
# Total T: 3684 Episode Num: 2871 Episode T: 1 Reward: 26.000
# Total T: 3685 Episode Num: 2871 Episode T: 2 Reward: 43.000
# Total T: 3697 Episode Num: 2881 Episode T: 1 Reward: 116.000
# Total T: 3711 Episode Num: 2891 Episode T: 1 Reward: 126.000
# Total T: 3725 Episode Num: 2901 Episode T: 1 Reward: 7.000
# Total T: 3726 Episode Num: 2901 Episode T: 2 Reward: 129.000
# Total T: 3739 Episode Num: 2911 Episode T: 1 Reward: 132.000
# Total T: 3753 Episode Num: 2921 Episode T: 1 Reward: 132.000
# Total T: 3763 Episode Num: 2931 Episode T: 1 Reward: -7.000
# Total T: 3775 Episode Num: 2941 Episode T: 1 Reward: 132.000
# Total T: 3786 Episode Num: 2951 Episode T: 1 Reward: 11.000
# Total T: 3787 Episode Num: 2951 Episode T: 2 Reward: 148.000
# Total T: 3798 Episode Num: 2961 Episode T: 1 Reward: 132.000
# Total T: 3814 Episode Num: 2971 Episode T: 1 Reward: 126.000
# Total T: 3831 Episode Num: 2981 Episode T: 1 Reward: 26.000
# Total T: 3832 Episode Num: 2981 Episode T: 2 Reward: 175.000
# Total T: 3842 Episode Num: 2991 Episode T: 1 Reward: 116.000
# Total T: 3855 Episode Num: 3001 Episode T: 1 Reward: 26.000
# Total T: 3856 Episode Num: 3001 Episode T: 2 Reward: 155.000
# Total T: 3870 Episode Num: 3011 Episode T: 1 Reward: 126.000
# Total T: 3883 Episode Num: 3021 Episode T: 1 Reward: 4.000
# Total T: 3897 Episode Num: 3031 Episode T: 1 Reward: 102.000
# Total T: 3909 Episode Num: 3041 Episode T: 1 Reward: 112.000
# Total T: 3920 Episode Num: 3051 Episode T: 1 Reward: 49.000
# Total T: 3934 Episode Num: 3061 Episode T: 1 Reward: 7.000
# Total T: 3935 Episode Num: 3061 Episode T: 2 Reward: 6.000
# Total T: 3946 Episode Num: 3071 Episode T: 1 Reward: 3.000
# Total T: 3957 Episode Num: 3081 Episode T: 1 Reward: 116.000
# Total T: 3970 Episode Num: 3091 Episode T: 1 Reward: 132.000
# Total T: 3983 Episode Num: 3101 Episode T: 1 Reward: 1.000
# Total T: 3984 Episode Num: 3101 Episode T: 2 Reward: 118.000
# Total T: 3995 Episode Num: 3111 Episode T: 1 Reward: 102.000
# Total T: 4006 Episode Num: 3121 Episode T: 1 Reward: 1.000
# Total T: 4007 Episode Num: 3121 Episode T: 2 Reward: 5.000
# Total T: 4020 Episode Num: 3131 Episode T: 1 Reward: 122.000
# Total T: 4030 Episode Num: 3141 Episode T: 1 Reward: 3.000
# Total T: 4042 Episode Num: 3151 Episode T: 1 Reward: 11.000
# Total T: 4043 Episode Num: 3151 Episode T: 2 Reward: 16.000
# Total T: 4055 Episode Num: 3161 Episode T: 1 Reward: 39.000
# Total T: 4066 Episode Num: 3171 Episode T: 1 Reward: 102.000
# Total T: 4078 Episode Num: 3181 Episode T: 1 Reward: 132.000
# Total T: 4088 Episode Num: 3191 Episode T: 1 Reward: 102.000
# Total T: 4099 Episode Num: 3201 Episode T: 1 Reward: 132.000
# Total T: 4112 Episode Num: 3211 Episode T: 1 Reward: 11.000
# Total T: 4113 Episode Num: 3211 Episode T: 2 Reward: 134.000
# Total T: 4123 Episode Num: 3221 Episode T: 1 Reward: 126.000
# Total T: 4137 Episode Num: 3231 Episode T: 1 Reward: 36.000
# Total T: 4138 Episode Num: 3231 Episode T: 2 Reward: 175.000
# Total T: 4155 Episode Num: 3241 Episode T: 1 Reward: 132.000
# Total T: 4169 Episode Num: 3251 Episode T: 1 Reward: 132.000
# Total T: 4181 Episode Num: 3261 Episode T: 1 Reward: 11.000
# Total T: 4182 Episode Num: 3261 Episode T: 2 Reward: 26.000
# Total T: 4194 Episode Num: 3271 Episode T: 1 Reward: 112.000
# Total T: 4204 Episode Num: 3281 Episode T: 1 Reward: 132.000
# Total T: 4214 Episode Num: 3291 Episode T: 1 Reward: 112.000
# Total T: 4224 Episode Num: 3301 Episode T: 1 Reward: 49.000
# Total T: 4238 Episode Num: 3311 Episode T: 1 Reward: 102.000
# Total T: 4251 Episode Num: 3321 Episode T: 1 Reward: 132.000
# Total T: 4261 Episode Num: 3331 Episode T: 1 Reward: 17.000
# Total T: 4262 Episode Num: 3331 Episode T: 2 Reward: 135.000
# Total T: 4276 Episode Num: 3341 Episode T: 1 Reward: 112.000
# Total T: 4287 Episode Num: 3351 Episode T: 1 Reward: 3.000
# Total T: 4302 Episode Num: 3361 Episode T: 1 Reward: 126.000
# Total T: 4312 Episode Num: 3371 Episode T: 1 Reward: 112.000
# Total T: 4326 Episode Num: 3381 Episode T: 1 Reward: 126.000
# Total T: 4338 Episode Num: 3391 Episode T: 1 Reward: 26.000
# Total T: 4339 Episode Num: 3391 Episode T: 2 Reward: 172.000
# Total T: 4349 Episode Num: 3401 Episode T: 1 Reward: 122.000
# Total T: 4362 Episode Num: 3411 Episode T: 1 Reward: 3.000
# Total T: 4373 Episode Num: 3421 Episode T: 1 Reward: 36.000
# Total T: 4374 Episode Num: 3421 Episode T: 2 Reward: 63.000
# Total T: 4388 Episode Num: 3431 Episode T: 1 Reward: 12.000
# Total T: 4389 Episode Num: 3431 Episode T: 2 Reward: 16.000
# Total T: 4407 Episode Num: 3441 Episode T: 1 Reward: 3.000
# Total T: 4420 Episode Num: 3451 Episode T: 1 Reward: 126.000
# Total T: 4430 Episode Num: 3461 Episode T: 1 Reward: 7.000
# Total T: 4431 Episode Num: 3461 Episode T: 2 Reward: -4.000
# Total T: 4443 Episode Num: 3471 Episode T: 1 Reward: -7.000
# Total T: 4456 Episode Num: 3481 Episode T: 1 Reward: 126.000
# Total T: 4467 Episode Num: 3491 Episode T: 1 Reward: 9.000
# Total T: 4483 Episode Num: 3501 Episode T: 1 Reward: 102.000
# Total T: 4494 Episode Num: 3511 Episode T: 1 Reward: 132.000
# Total T: 4505 Episode Num: 3521 Episode T: 1 Reward: 3.000
# Total T: 4515 Episode Num: 3531 Episode T: 1 Reward: 132.000
# Total T: 4528 Episode Num: 3541 Episode T: 1 Reward: 116.000
# Total T: 4540 Episode Num: 3551 Episode T: 1 Reward: -7.000
# Total T: 4553 Episode Num: 3561 Episode T: 1 Reward: 116.000
# Total T: 4566 Episode Num: 3571 Episode T: 1 Reward: 26.000
# Total T: 4567 Episode Num: 3571 Episode T: 2 Reward: 99.000
# Total T: 4580 Episode Num: 3581 Episode T: 1 Reward: 102.000
# Total T: 4592 Episode Num: 3591 Episode T: 1 Reward: 116.000
# Total T: 4603 Episode Num: 3601 Episode T: 1 Reward: 126.000
# Total T: 4613 Episode Num: 3611 Episode T: 1 Reward: 11.000
# Total T: 4614 Episode Num: 3611 Episode T: 2 Reward: 15.000
# Total T: 4628 Episode Num: 3621 Episode T: 1 Reward: 126.000
# Total T: 4639 Episode Num: 3631 Episode T: 1 Reward: 112.000
# Total T: 4652 Episode Num: 3641 Episode T: 1 Reward: 11.000
# Total T: 4653 Episode Num: 3641 Episode T: 2 Reward: 23.000
# Total T: 4654 Episode Num: 3641 Episode T: 3 Reward: 167.000
# Total T: 4665 Episode Num: 3651 Episode T: 1 Reward: 116.000
# Total T: 4679 Episode Num: 3661 Episode T: 1 Reward: 126.000
# Total T: 4691 Episode Num: 3671 Episode T: 1 Reward: 132.000
# Total T: 4703 Episode Num: 3681 Episode T: 1 Reward: 126.000
# Total T: 4716 Episode Num: 3691 Episode T: 1 Reward: 9.000
# Total T: 4732 Episode Num: 3701 Episode T: 1 Reward: 126.000
# Total T: 4743 Episode Num: 3711 Episode T: 1 Reward: -6.000
# Total T: 4755 Episode Num: 3721 Episode T: 1 Reward: 36.000
# Total T: 4756 Episode Num: 3721 Episode T: 2 Reward: 56.000
# Total T: 4757 Episode Num: 3721 Episode T: 3 Reward: 208.000
# Total T: 4769 Episode Num: 3731 Episode T: 1 Reward: 102.000
# Total T: 4783 Episode Num: 3741 Episode T: 1 Reward: 7.000
# Total T: 4784 Episode Num: 3741 Episode T: 2 Reward: 129.000
# Total T: 4797 Episode Num: 3751 Episode T: 1 Reward: 11.000
# Total T: 4798 Episode Num: 3751 Episode T: 2 Reward: 148.000
# Total T: 4812 Episode Num: 3761 Episode T: 1 Reward: 3.000
# Total T: 4826 Episode Num: 3771 Episode T: 1 Reward: 112.000
# Total T: 4838 Episode Num: 3781 Episode T: 1 Reward: 126.000
# Total T: 4851 Episode Num: 3791 Episode T: 1 Reward: 102.000
# Total T: 4864 Episode Num: 3801 Episode T: 1 Reward: 132.000
# Total T: 4880 Episode Num: 3811 Episode T: 1 Reward: 3.000
# Total T: 4891 Episode Num: 3821 Episode T: 1 Reward: 126.000
# Total T: 4901 Episode Num: 3831 Episode T: 1 Reward: -7.000
# Total T: 4917 Episode Num: 3841 Episode T: 1 Reward: 126.000
# Total T: 4930 Episode Num: 3851 Episode T: 1 Reward: 102.000
# Total T: 4942 Episode Num: 3861 Episode T: 1 Reward: 112.000
# Total T: 4955 Episode Num: 3871 Episode T: 1 Reward: 36.000
# Total T: 4956 Episode Num: 3871 Episode T: 2 Reward: 182.000
# Total T: 4969 Episode Num: 3881 Episode T: 1 Reward: 11.000
# Total T: 4970 Episode Num: 3881 Episode T: 2 Reward: 15.000
# Total T: 4984 Episode Num: 3891 Episode T: 1 Reward: 112.000
# Total T: 5001 Episode Num: 3901 Episode T: 1 Reward: 12.000
# Total T: 5002 Episode Num: 3901 Episode T: 2 Reward: 155.000
# Total T: 5015 Episode Num: 3911 Episode T: 1 Reward: 112.000
# Total T: 5025 Episode Num: 3921 Episode T: 1 Reward: 112.000
# Total T: 5039 Episode Num: 3931 Episode T: 1 Reward: 3.000
# Total T: 5051 Episode Num: 3941 Episode T: 1 Reward: 132.000
# Total T: 5061 Episode Num: 3951 Episode T: 1 Reward: 102.000
# Total T: 5074 Episode Num: 3961 Episode T: 1 Reward: 116.000
# Total T: 5085 Episode Num: 3971 Episode T: 1 Reward: 12.000
# Total T: 5086 Episode Num: 3971 Episode T: 2 Reward: 24.000
# Total T: 5087 Episode Num: 3971 Episode T: 3 Reward: 138.000
# Total T: 5105 Episode Num: 3981 Episode T: 1 Reward: 132.000
# Total T: 5117 Episode Num: 3991 Episode T: 1 Reward: 3.000
# Total T: 5132 Episode Num: 4001 Episode T: 1 Reward: 1.000
# Total T: 5133 Episode Num: 4001 Episode T: 2 Reward: 114.000
# Total T: 5147 Episode Num: 4011 Episode T: 1 Reward: 102.000
# Total T: 5159 Episode Num: 4021 Episode T: 1 Reward: 132.000
# Total T: 5170 Episode Num: 4031 Episode T: 1 Reward: 7.000
# Total T: 5171 Episode Num: 4031 Episode T: 2 Reward: 44.000
# Total T: 5172 Episode Num: 4031 Episode T: 3 Reward: 179.000
# Total T: 5187 Episode Num: 4041 Episode T: 1 Reward: 126.000
# Total T: 5198 Episode Num: 4051 Episode T: 1 Reward: 126.000
# Total T: 5211 Episode Num: 4061 Episode T: 1 Reward: 132.000
# Total T: 5227 Episode Num: 4071 Episode T: 1 Reward: 122.000
# Total T: 5241 Episode Num: 4081 Episode T: 1 Reward: 126.000
# Total T: 5256 Episode Num: 4091 Episode T: 1 Reward: 17.000
# Total T: 5257 Episode Num: 4091 Episode T: 2 Reward: 125.000
# Total T: 5268 Episode Num: 4101 Episode T: 1 Reward: 126.000
# Total T: 5279 Episode Num: 4111 Episode T: 1 Reward: 132.000
# Total T: 5295 Episode Num: 4121 Episode T: 1 Reward: 132.000
# Total T: 5306 Episode Num: 4131 Episode T: 1 Reward: 132.000
# Total T: 5319 Episode Num: 4141 Episode T: 1 Reward: 132.000
# Total T: 5332 Episode Num: 4151 Episode T: 1 Reward: 132.000
# Total T: 5344 Episode Num: 4161 Episode T: 1 Reward: 112.000
# Total T: 5356 Episode Num: 4171 Episode T: 1 Reward: 1.000
# Total T: 5357 Episode Num: 4171 Episode T: 2 Reward: 3.000
# Total T: 5358 Episode Num: 4171 Episode T: 3 Reward: 131.000
# Total T: 5369 Episode Num: 4181 Episode T: 1 Reward: 112.000
# Total T: 5382 Episode Num: 4191 Episode T: 1 Reward: 102.000
# Total T: 5395 Episode Num: 4201 Episode T: 1 Reward: 11.000
# Total T: 5396 Episode Num: 4201 Episode T: 2 Reward: 25.000
# Total T: 5410 Episode Num: 4211 Episode T: 1 Reward: 126.000
# Total T: 5421 Episode Num: 4221 Episode T: 1 Reward: 112.000
# Total T: 5435 Episode Num: 4231 Episode T: 1 Reward: 3.000
# Total T: 5447 Episode Num: 4241 Episode T: 1 Reward: 49.000
# Total T: 5460 Episode Num: 4251 Episode T: 1 Reward: 132.000
# Total T: 5472 Episode Num: 4261 Episode T: 1 Reward: 132.000
# Total T: 5482 Episode Num: 4271 Episode T: 1 Reward: 17.000
# Total T: 5483 Episode Num: 4271 Episode T: 2 Reward: 21.000
# Total T: 5494 Episode Num: 4281 Episode T: 1 Reward: 112.000
# Total T: 5505 Episode Num: 4291 Episode T: 1 Reward: 2.000
# Total T: 5506 Episode Num: 4291 Episode T: 2 Reward: 135.000
# Total T: 5519 Episode Num: 4301 Episode T: 1 Reward: 126.000
# Total T: 5532 Episode Num: 4311 Episode T: 1 Reward: 126.000
# Total T: 5547 Episode Num: 4321 Episode T: 1 Reward: 126.000
# Total T: 5560 Episode Num: 4331 Episode T: 1 Reward: -7.000
# Total T: 5571 Episode Num: 4341 Episode T: 1 Reward: 102.000
# Total T: 5584 Episode Num: 4351 Episode T: 1 Reward: 4.000
# Total T: 5596 Episode Num: 4361 Episode T: 1 Reward: 132.000
# Total T: 5606 Episode Num: 4371 Episode T: 1 Reward: 1.000
# Total T: 5607 Episode Num: 4371 Episode T: 2 Reward: 128.000
# Total T: 5618 Episode Num: 4381 Episode T: 1 Reward: 112.000
# Total T: 5628 Episode Num: 4391 Episode T: 1 Reward: 126.000
# Total T: 5641 Episode Num: 4401 Episode T: 1 Reward: 132.000
# Total T: 5653 Episode Num: 4411 Episode T: 1 Reward: 132.000
# Total T: 5664 Episode Num: 4421 Episode T: 1 Reward: 132.000
# Total T: 5674 Episode Num: 4431 Episode T: 1 Reward: 132.000
# Total T: 5686 Episode Num: 4441 Episode T: 1 Reward: 112.000
# Total T: 5698 Episode Num: 4451 Episode T: 1 Reward: 26.000
# Total T: 5699 Episode Num: 4451 Episode T: 2 Reward: 41.000
# Total T: 5700 Episode Num: 4451 Episode T: 3 Reward: 67.000
# Total T: 5701 Episode Num: 4451 Episode T: 4 Reward: 208.000
# Total T: 5712 Episode Num: 4461 Episode T: 1 Reward: 3.000
# Total T: 5726 Episode Num: 4471 Episode T: 1 Reward: 36.000
# Total T: 5727 Episode Num: 4471 Episode T: 2 Reward: 182.000
# Total T: 5738 Episode Num: 4481 Episode T: 1 Reward: 132.000
# Total T: 5748 Episode Num: 4491 Episode T: 1 Reward: 126.000
# Total T: 5761 Episode Num: 4501 Episode T: 1 Reward: 11.000
# Total T: 5762 Episode Num: 4501 Episode T: 2 Reward: 144.000
# Total T: 5775 Episode Num: 4511 Episode T: 1 Reward: 112.000
# Total T: 5789 Episode Num: 4521 Episode T: 1 Reward: 17.000
# Total T: 5790 Episode Num: 4521 Episode T: 2 Reward: 155.000
# Total T: 5803 Episode Num: 4531 Episode T: 1 Reward: 12.000
# Total T: 5804 Episode Num: 4531 Episode T: 2 Reward: 59.000
# Total T: 5805 Episode Num: 4531 Episode T: 3 Reward: 195.000
# Total T: 5816 Episode Num: 4541 Episode T: 1 Reward: 102.000
# Total T: 5829 Episode Num: 4551 Episode T: 1 Reward: 11.000
# Total T: 5830 Episode Num: 4551 Episode T: 2 Reward: 48.000
# Total T: 5831 Episode Num: 4551 Episode T: 3 Reward: 188.000
# Total T: 5844 Episode Num: 4561 Episode T: 1 Reward: 132.000
# Total T: 5855 Episode Num: 4571 Episode T: 1 Reward: -7.000
# Total T: 5866 Episode Num: 4581 Episode T: 1 Reward: 11.000
# Total T: 5867 Episode Num: 4581 Episode T: 2 Reward: 154.000
# Total T: 5879 Episode Num: 4591 Episode T: 1 Reward: 102.000
# Total T: 5892 Episode Num: 4601 Episode T: 1 Reward: 126.000
# Total T: 5904 Episode Num: 4611 Episode T: 1 Reward: -7.000
# Total T: 5916 Episode Num: 4621 Episode T: 1 Reward: 132.000
# Total T: 5926 Episode Num: 4631 Episode T: 1 Reward: 1.000
# Total T: 5927 Episode Num: 4631 Episode T: 2 Reward: 13.000
# Total T: 5928 Episode Num: 4631 Episode T: 3 Reward: 157.000
# Total T: 5939 Episode Num: 4641 Episode T: 1 Reward: 132.000
# Total T: 5950 Episode Num: 4651 Episode T: 1 Reward: 126.000
# Total T: 5962 Episode Num: 4661 Episode T: 1 Reward: 12.000
# Total T: 5963 Episode Num: 4661 Episode T: 2 Reward: 40.000
# Total T: 5964 Episode Num: 4661 Episode T: 3 Reward: 79.000
# Total T: 5965 Episode Num: 4661 Episode T: 4 Reward: 228.000
# Total T: 5976 Episode Num: 4671 Episode T: 1 Reward: 28.000
# Total T: 5988 Episode Num: 4681 Episode T: 1 Reward: 122.000
# Total T: 5998 Episode Num: 4691 Episode T: 1 Reward: 3.000
# Total T: 6009 Episode Num: 4701 Episode T: 1 Reward: 1.000
# Total T: 6010 Episode Num: 4701 Episode T: 2 Reward: 13.000
# Total T: 6011 Episode Num: 4701 Episode T: 3 Reward: 151.000
# Total T: 6023 Episode Num: 4711 Episode T: 1 Reward: 132.000
# Total T: 6035 Episode Num: 4721 Episode T: 1 Reward: 116.000
# Total T: 6047 Episode Num: 4731 Episode T: 1 Reward: 116.000
# Total T: 6060 Episode Num: 4741 Episode T: 1 Reward: 112.000
# Total T: 6070 Episode Num: 4751 Episode T: 1 Reward: 112.000
# Total T: 6082 Episode Num: 4761 Episode T: 1 Reward: 132.000
# Total T: 6094 Episode Num: 4771 Episode T: 1 Reward: 116.000
# Total T: 6104 Episode Num: 4781 Episode T: 1 Reward: 132.000
# Total T: 6116 Episode Num: 4791 Episode T: 1 Reward: 132.000
# Total T: 6128 Episode Num: 4801 Episode T: 1 Reward: 132.000
# Total T: 6146 Episode Num: 4811 Episode T: 1 Reward: 116.000
# Total T: 6162 Episode Num: 4821 Episode T: 1 Reward: 132.000
# Total T: 6173 Episode Num: 4831 Episode T: 1 Reward: 1.000
# Total T: 6174 Episode Num: 4831 Episode T: 2 Reward: -5.000
# Total T: 6189 Episode Num: 4841 Episode T: 1 Reward: 122.000
# Total T: 6202 Episode Num: 4851 Episode T: 1 Reward: 132.000
# Total T: 6213 Episode Num: 4861 Episode T: 1 Reward: 12.000
# Total T: 6214 Episode Num: 4861 Episode T: 2 Reward: 34.000
# Total T: 6215 Episode Num: 4861 Episode T: 3 Reward: 158.000
# Total T: 6226 Episode Num: 4871 Episode T: 1 Reward: 112.000
# Total T: 6237 Episode Num: 4881 Episode T: 1 Reward: 26.000
# Total T: 6238 Episode Num: 4881 Episode T: 2 Reward: 41.000
# Total T: 6239 Episode Num: 4881 Episode T: 3 Reward: 178.000
# Total T: 6251 Episode Num: 4891 Episode T: 1 Reward: 36.000
# Total T: 6252 Episode Num: 4891 Episode T: 2 Reward: 151.000
# Total T: 6265 Episode Num: 4901 Episode T: 1 Reward: -7.000
# Total T: 6278 Episode Num: 4911 Episode T: 1 Reward: 122.000
# Total T: 6290 Episode Num: 4921 Episode T: 1 Reward: 126.000
# Total T: 6302 Episode Num: 4931 Episode T: 1 Reward: -7.000
# Total T: 6315 Episode Num: 4941 Episode T: 1 Reward: 2.000
# Total T: 6316 Episode Num: 4941 Episode T: 2 Reward: 14.000
# Total T: 6317 Episode Num: 4941 Episode T: 3 Reward: 158.000
# Total T: 6328 Episode Num: 4951 Episode T: 1 Reward: 116.000
# Total T: 6342 Episode Num: 4961 Episode T: 1 Reward: 112.000
# Total T: 6356 Episode Num: 4971 Episode T: 1 Reward: 11.000
# Total T: 6357 Episode Num: 4971 Episode T: 2 Reward: 15.000
# Total T: 6367 Episode Num: 4981 Episode T: 1 Reward: 126.000
# Total T: 6380 Episode Num: 4991 Episode T: 1 Reward: 112.000
# Total T: 6394 Episode Num: 5001 Episode T: 1 Reward: -7.000
# Total T: 6405 Episode Num: 5011 Episode T: 1 Reward: 132.000
# Total T: 6416 Episode Num: 5021 Episode T: 1 Reward: 132.000
# Total T: 6426 Episode Num: 5031 Episode T: 1 Reward: 1.000
# Total T: 6427 Episode Num: 5031 Episode T: 2 Reward: 118.000
# Total T: 6437 Episode Num: 5041 Episode T: 1 Reward: 11.000
# Total T: 6438 Episode Num: 5041 Episode T: 2 Reward: 148.000
# Total T: 6451 Episode Num: 5051 Episode T: 1 Reward: -7.000
# Total T: 6466 Episode Num: 5061 Episode T: 1 Reward: 112.000
# Total T: 6480 Episode Num: 5071 Episode T: 1 Reward: 112.000
# Total T: 6491 Episode Num: 5081 Episode T: 1 Reward: 3.000
# Total T: 6504 Episode Num: 5091 Episode T: 1 Reward: -7.000
# Total T: 6520 Episode Num: 5101 Episode T: 1 Reward: 102.000
# Total T: 6531 Episode Num: 5111 Episode T: 1 Reward: 12.000
# Total T: 6532 Episode Num: 5111 Episode T: 2 Reward: 16.000
# Total T: 6544 Episode Num: 5121 Episode T: 1 Reward: 132.000
# Total T: 6559 Episode Num: 5131 Episode T: 1 Reward: 17.000
# Total T: 6560 Episode Num: 5131 Episode T: 2 Reward: 155.000
# Total T: 6574 Episode Num: 5141 Episode T: 1 Reward: 132.000
# Total T: 6589 Episode Num: 5151 Episode T: 1 Reward: 132.000
# Total T: 6601 Episode Num: 5161 Episode T: 1 Reward: 112.000
# Total T: 6615 Episode Num: 5171 Episode T: 1 Reward: 112.000
# Total T: 6627 Episode Num: 5181 Episode T: 1 Reward: 7.000
# Total T: 6628 Episode Num: 5181 Episode T: 2 Reward: 115.000
# Total T: 6641 Episode Num: 5191 Episode T: 1 Reward: 102.000
# Total T: 6652 Episode Num: 5201 Episode T: 1 Reward: 132.000
# Total T: 6668 Episode Num: 5211 Episode T: 1 Reward: 132.000
# Total T: 6682 Episode Num: 5221 Episode T: 1 Reward: 1.000
# Total T: 6683 Episode Num: 5221 Episode T: 2 Reward: 11.000
# Total T: 6695 Episode Num: 5231 Episode T: 1 Reward: 116.000
# Total T: 6706 Episode Num: 5241 Episode T: 1 Reward: 132.000
# Total T: 6720 Episode Num: 5251 Episode T: 1 Reward: 36.000
# Total T: 6721 Episode Num: 5251 Episode T: 2 Reward: 161.000
# Total T: 6734 Episode Num: 5261 Episode T: 1 Reward: 102.000
# Total T: 6747 Episode Num: 5271 Episode T: 1 Reward: 49.000
# Total T: 6761 Episode Num: 5281 Episode T: 1 Reward: 116.000
# Total T: 6773 Episode Num: 5291 Episode T: 1 Reward: 126.000
# Total T: 6785 Episode Num: 5301 Episode T: 1 Reward: -7.000
# Total T: 6798 Episode Num: 5311 Episode T: 1 Reward: 11.000
# Total T: 6799 Episode Num: 5311 Episode T: 2 Reward: 124.000
# Total T: 6813 Episode Num: 5321 Episode T: 1 Reward: 7.000
# Total T: 6814 Episode Num: 5321 Episode T: 2 Reward: 14.000
# Total T: 6815 Episode Num: 5321 Episode T: 3 Reward: 19.000
# Total T: 6830 Episode Num: 5331 Episode T: 1 Reward: -7.000
# Total T: 6841 Episode Num: 5341 Episode T: 1 Reward: 132.000
# Total T: 6852 Episode Num: 5351 Episode T: 1 Reward: 132.000
# Total T: 6863 Episode Num: 5361 Episode T: 1 Reward: 3.000
# Total T: 6876 Episode Num: 5371 Episode T: 1 Reward: 126.000
# Total T: 6887 Episode Num: 5381 Episode T: 1 Reward: 31.000
# Total T: 6888 Episode Num: 5381 Episode T: 2 Reward: 48.000
# Total T: 6900 Episode Num: 5391 Episode T: 1 Reward: 17.000
# Total T: 6901 Episode Num: 5391 Episode T: 2 Reward: 139.000
# Total T: 6914 Episode Num: 5401 Episode T: 1 Reward: -7.000
# Total T: 6927 Episode Num: 5411 Episode T: 1 Reward: 132.000
# Total T: 6941 Episode Num: 5421 Episode T: 1 Reward: 132.000
# Total T: 6953 Episode Num: 5431 Episode T: 1 Reward: 11.000
# Total T: 6954 Episode Num: 5431 Episode T: 2 Reward: 25.000
# Total T: 6969 Episode Num: 5441 Episode T: 1 Reward: 126.000
# Total T: 6980 Episode Num: 5451 Episode T: 1 Reward: 102.000
# Total T: 6992 Episode Num: 5461 Episode T: 1 Reward: 3.000
# Total T: 7006 Episode Num: 5471 Episode T: 1 Reward: 4.000
# Total T: 7022 Episode Num: 5481 Episode T: 1 Reward: 12.000
# Total T: 7023 Episode Num: 5481 Episode T: 2 Reward: 155.000
# Total T: 7037 Episode Num: 5491 Episode T: 1 Reward: 132.000
# Total T: 7048 Episode Num: 5501 Episode T: 1 Reward: 11.000
# Total T: 7049 Episode Num: 5501 Episode T: 2 Reward: 148.000
# Total T: 7064 Episode Num: 5511 Episode T: 1 Reward: 102.000
# Total T: 7076 Episode Num: 5521 Episode T: 1 Reward: 49.000
# Total T: 7092 Episode Num: 5531 Episode T: 1 Reward: 112.000
# Total T: 7102 Episode Num: 5541 Episode T: 1 Reward: 132.000
# Total T: 7116 Episode Num: 5551 Episode T: 1 Reward: 3.000
# Total T: 7127 Episode Num: 5561 Episode T: 1 Reward: 132.000
# Total T: 7139 Episode Num: 5571 Episode T: 1 Reward: 11.000
# Total T: 7140 Episode Num: 5571 Episode T: 2 Reward: 154.000
# Total T: 7153 Episode Num: 5581 Episode T: 1 Reward: 132.000
# Total T: 7163 Episode Num: 5591 Episode T: 1 Reward: 132.000
# Total T: 7175 Episode Num: 5601 Episode T: 1 Reward: 126.000
# Total T: 7187 Episode Num: 5611 Episode T: 1 Reward: 132.000
# Total T: 7201 Episode Num: 5621 Episode T: 1 Reward: 126.000
# Total T: 7212 Episode Num: 5631 Episode T: 1 Reward: 112.000
# Total T: 7226 Episode Num: 5641 Episode T: 1 Reward: 132.000
# Total T: 7238 Episode Num: 5651 Episode T: 1 Reward: 112.000
# Total T: 7248 Episode Num: 5661 Episode T: 1 Reward: 126.000
# Total T: 7261 Episode Num: 5671 Episode T: 1 Reward: 1.000
# Total T: 7262 Episode Num: 5671 Episode T: 2 Reward: 3.000
# Total T: 7263 Episode Num: 5671 Episode T: 3 Reward: 117.000
# Total T: 7275 Episode Num: 5681 Episode T: 1 Reward: 132.000
# Total T: 7289 Episode Num: 5691 Episode T: 1 Reward: 11.000
# Total T: 7290 Episode Num: 5691 Episode T: 2 Reward: 154.000
# Total T: 7306 Episode Num: 5701 Episode T: 1 Reward: 116.000
# Total T: 7320 Episode Num: 5711 Episode T: 1 Reward: 4.000
# Total T: 7334 Episode Num: 5721 Episode T: 1 Reward: 132.000
# Total T: 7348 Episode Num: 5731 Episode T: 1 Reward: 9.000
# Total T: 7361 Episode Num: 5741 Episode T: 1 Reward: 102.000
# Total T: 7372 Episode Num: 5751 Episode T: 1 Reward: 132.000
# Total T: 7382 Episode Num: 5761 Episode T: 1 Reward: 126.000
# Total T: 7394 Episode Num: 5771 Episode T: 1 Reward: -7.000
# Total T: 7405 Episode Num: 5781 Episode T: 1 Reward: 3.000
# Total T: 7422 Episode Num: 5791 Episode T: 1 Reward: 3.000
# Total T: 7432 Episode Num: 5801 Episode T: 1 Reward: 3.000
# Total T: 7444 Episode Num: 5811 Episode T: 1 Reward: 1.000
# Total T: 7445 Episode Num: 5811 Episode T: 2 Reward: 128.000
# Total T: 7459 Episode Num: 5821 Episode T: 1 Reward: 11.000
# Total T: 7460 Episode Num: 5821 Episode T: 2 Reward: 154.000
# Total T: 7475 Episode Num: 5831 Episode T: 1 Reward: 26.000
# Total T: 7476 Episode Num: 5831 Episode T: 2 Reward: 43.000
# Total T: 7486 Episode Num: 5841 Episode T: 1 Reward: 132.000
# Total T: 7502 Episode Num: 5851 Episode T: 1 Reward: 126.000
# Total T: 7513 Episode Num: 5861 Episode T: 1 Reward: 112.000
# Total T: 7526 Episode Num: 5871 Episode T: 1 Reward: 126.000
# Total T: 7538 Episode Num: 5881 Episode T: 1 Reward: 26.000
# Total T: 7539 Episode Num: 5881 Episode T: 2 Reward: 162.000
# Total T: 7549 Episode Num: 5891 Episode T: 1 Reward: 102.000
# Total T: 7560 Episode Num: 5901 Episode T: 1 Reward: 3.000
# Total T: 7571 Episode Num: 5911 Episode T: 1 Reward: 112.000
# Total T: 7584 Episode Num: 5921 Episode T: 1 Reward: 112.000
# Total T: 7596 Episode Num: 5931 Episode T: 1 Reward: 112.000
# Total T: 7606 Episode Num: 5941 Episode T: 1 Reward: 36.000
# Total T: 7607 Episode Num: 5941 Episode T: 2 Reward: 182.000
# Total T: 7618 Episode Num: 5951 Episode T: 1 Reward: 3.000
# Total T: 7630 Episode Num: 5961 Episode T: 1 Reward: 132.000
# Total T: 7640 Episode Num: 5971 Episode T: 1 Reward: 116.000
# Total T: 7651 Episode Num: 5981 Episode T: 1 Reward: 132.000
# Total T: 7663 Episode Num: 5991 Episode T: 1 Reward: 2.000
# Total T: 7664 Episode Num: 5991 Episode T: 2 Reward: 115.000
# Total T: 7676 Episode Num: 6001 Episode T: 1 Reward: 126.000
# Total T: 7686 Episode Num: 6011 Episode T: 1 Reward: 132.000
# Total T: 7698 Episode Num: 6021 Episode T: 1 Reward: 1.000
# Total T: 7699 Episode Num: 6021 Episode T: 2 Reward: 134.000
# Total T: 7710 Episode Num: 6031 Episode T: 1 Reward: 49.000
# Total T: 7720 Episode Num: 6041 Episode T: 1 Reward: 57.000
# Total T: 7721 Episode Num: 6041 Episode T: 2 Reward: 95.000
# Total T: 7722 Episode Num: 6041 Episode T: 3 Reward: 121.000
# Total T: 7741 Episode Num: 6051 Episode T: 1 Reward: 132.000
# Total T: 7757 Episode Num: 6061 Episode T: 1 Reward: 126.000
# Total T: 7774 Episode Num: 6071 Episode T: 1 Reward: 132.000
# Total T: 7786 Episode Num: 6081 Episode T: 1 Reward: 1.000
# Total T: 7787 Episode Num: 6081 Episode T: 2 Reward: 6.000
# Total T: 7798 Episode Num: 6091 Episode T: 1 Reward: 132.000
# Total T: 7813 Episode Num: 6101 Episode T: 1 Reward: 132.000
# Total T: 7826 Episode Num: 6111 Episode T: 1 Reward: 132.000
# Total T: 7836 Episode Num: 6121 Episode T: 1 Reward: 132.000
# Total T: 7853 Episode Num: 6131 Episode T: 1 Reward: 17.000
# Total T: 7854 Episode Num: 6131 Episode T: 2 Reward: 135.000
# Total T: 7866 Episode Num: 6141 Episode T: 1 Reward: 132.000
# Total T: 7877 Episode Num: 6151 Episode T: 1 Reward: 28.000
# Total T: 7889 Episode Num: 6161 Episode T: 1 Reward: 26.000
# Total T: 7890 Episode Num: 6161 Episode T: 2 Reward: 80.000
# Total T: 7891 Episode Num: 6161 Episode T: 3 Reward: 234.000
# Total T: 7903 Episode Num: 6171 Episode T: 1 Reward: 11.000
# Total T: 7904 Episode Num: 6171 Episode T: 2 Reward: 15.000
# Total T: 7916 Episode Num: 6181 Episode T: 1 Reward: 36.000
# Total T: 7917 Episode Num: 6181 Episode T: 2 Reward: 63.000
# Total T: 7932 Episode Num: 6191 Episode T: 1 Reward: 9.000
# Total T: 7942 Episode Num: 6201 Episode T: 1 Reward: 102.000
# ...
# Total T: 47540 Episode Num: 29251 Episode T: 1 Reward: 1.000
# Total T: 47541 Episode Num: 29251 Episode T: 2 Reward: 13.000
# Total T: 47542 Episode Num: 29251 Episode T: 3 Reward: 28.000
# Total T: 47563 Episode Num: 29261 Episode T: 1 Reward: 11.000
# Total T: 47564 Episode Num: 29261 Episode T: 2 Reward: 25.000
# Total T: 47579 Episode Num: 29271 Episode T: 1 Reward: 3.000
# Total T: 47602 Episode Num: 29281 Episode T: 1 Reward: 3.000
# Total T: 47620 Episode Num: 29291 Episode T: 1 Reward: -7.000
# Total T: 47646 Episode Num: 29301 Episode T: 1 Reward: 1.000
# Total T: 47647 Episode Num: 29301 Episode T: 2 Reward: 13.000
# Total T: 47648 Episode Num: 29301 Episode T: 3 Reward: 18.000
# Total T: 47673 Episode Num: 29311 Episode T: 1 Reward: 1.000
# Total T: 47674 Episode Num: 29311 Episode T: 2 Reward: 5.000
# Total T: 47698 Episode Num: 29321 Episode T: 1 Reward: 3.000
# Total T: 47724 Episode Num: 29331 Episode T: 1 Reward: 11.000
# Total T: 47725 Episode Num: 29331 Episode T: 2 Reward: 15.000
# Total T: 47744 Episode Num: 29341 Episode T: 1 Reward: 1.000
# Total T: 47745 Episode Num: 29341 Episode T: 2 Reward: 13.000
# Total T: 47746 Episode Num: 29341 Episode T: 3 Reward: 28.000
# Total T: 47765 Episode Num: 29351 Episode T: 1 Reward: 11.000
# Total T: 47766 Episode Num: 29351 Episode T: 2 Reward: 33.000
# Total T: 47767 Episode Num: 29351 Episode T: 3 Reward: 56.000
# Total T: 47768 Episode Num: 29351 Episode T: 4 Reward: 72.000
# Total T: 47789 Episode Num: 29361 Episode T: 1 Reward: 1.000
# Total T: 47790 Episode Num: 29361 Episode T: 2 Reward: 13.000
# Total T: 47791 Episode Num: 29361 Episode T: 3 Reward: 26.000
# Total T: 47792 Episode Num: 29361 Episode T: 4 Reward: 32.000
# Total T: 47814 Episode Num: 29371 Episode T: 1 Reward: 11.000
# Total T: 47815 Episode Num: 29371 Episode T: 2 Reward: 33.000
# Total T: 47816 Episode Num: 29371 Episode T: 3 Reward: 48.000
# Total T: 47831 Episode Num: 29381 Episode T: 1 Reward: 11.000
# Total T: 47832 Episode Num: 29381 Episode T: 2 Reward: 23.000
# Total T: 47833 Episode Num: 29381 Episode T: 3 Reward: 46.000
# Total T: 47834 Episode Num: 29381 Episode T: 4 Reward: 62.000
# Total T: 47854 Episode Num: 29391 Episode T: 1 Reward: 1.000
# Total T: 47855 Episode Num: 29391 Episode T: 2 Reward: 3.000
# Total T: 47856 Episode Num: 29391 Episode T: 3 Reward: 6.000
# Total T: 47857 Episode Num: 29391 Episode T: 4 Reward: 10.000
# Total T: 47858 Episode Num: 29391 Episode T: 5 Reward: 15.000
# Total T: 47859 Episode Num: 29391 Episode T: 6 Reward: 23.000
# Total T: 47877 Episode Num: 29401 Episode T: 1 Reward: 11.000
# Total T: 47878 Episode Num: 29401 Episode T: 2 Reward: 15.000
# Total T: 47897 Episode Num: 29411 Episode T: 1 Reward: 11.000
# Total T: 47898 Episode Num: 29411 Episode T: 2 Reward: 15.000
# Total T: 47918 Episode Num: 29421 Episode T: 1 Reward: 3.000
# Total T: 47936 Episode Num: 29431 Episode T: 1 Reward: -7.000
# Total T: 47957 Episode Num: 29441 Episode T: 1 Reward: 3.000
# Total T: 47974 Episode Num: 29451 Episode T: 1 Reward: -7.000
# Total T: 47991 Episode Num: 29461 Episode T: 1 Reward: 1.000
# Total T: 47992 Episode Num: 29461 Episode T: 2 Reward: 13.000
# Total T: 47993 Episode Num: 29461 Episode T: 3 Reward: 18.000
# Total T: 48008 Episode Num: 29471 Episode T: 1 Reward: 3.000
# Total T: 48023 Episode Num: 29481 Episode T: 1 Reward: -7.000
# Total T: 48041 Episode Num: 29491 Episode T: 1 Reward: 1.000
# Total T: 48042 Episode Num: 29491 Episode T: 2 Reward: -5.000
# Total T: 48068 Episode Num: 29501 Episode T: 1 Reward: 1.000
# Total T: 48069 Episode Num: 29501 Episode T: 2 Reward: 5.000
# Total T: 48086 Episode Num: 29511 Episode T: 1 Reward: 11.000
# Total T: 48087 Episode Num: 29511 Episode T: 2 Reward: 23.000
# Total T: 48088 Episode Num: 29511 Episode T: 3 Reward: 38.000
# Total T: 48105 Episode Num: 29521 Episode T: 1 Reward: 1.000
# Total T: 48106 Episode Num: 29521 Episode T: 2 Reward: 13.000
# Total T: 48107 Episode Num: 29521 Episode T: 3 Reward: 26.000
# Total T: 48108 Episode Num: 29521 Episode T: 4 Reward: 50.000
# Total T: 48109 Episode Num: 29521 Episode T: 5 Reward: 85.000
# Total T: 48110 Episode Num: 29521 Episode T: 6 Reward: 131.000
# Total T: 48111 Episode Num: 29521 Episode T: 7 Reward: 170.000
# Total T: 48132 Episode Num: 29531 Episode T: 1 Reward: 1.000
# Total T: 48133 Episode Num: 29531 Episode T: 2 Reward: 13.000
# Total T: 48134 Episode Num: 29531 Episode T: 3 Reward: 18.000
# Total T: 48151 Episode Num: 29541 Episode T: 1 Reward: 11.000
# Total T: 48152 Episode Num: 29541 Episode T: 2 Reward: 15.000
# Total T: 48178 Episode Num: 29551 Episode T: 1 Reward: 11.000
# Total T: 48179 Episode Num: 29551 Episode T: 2 Reward: 33.000
# Total T: 48180 Episode Num: 29551 Episode T: 3 Reward: 48.000
# Total T: 48202 Episode Num: 29561 Episode T: 1 Reward: 11.000
# Total T: 48203 Episode Num: 29561 Episode T: 2 Reward: 25.000
# Total T: 48225 Episode Num: 29571 Episode T: 1 Reward: 11.000
# Total T: 48226 Episode Num: 29571 Episode T: 2 Reward: 23.000
# Total T: 48227 Episode Num: 29571 Episode T: 3 Reward: 38.000
# Total T: 48243 Episode Num: 29581 Episode T: 1 Reward: 11.000
# Total T: 48244 Episode Num: 29581 Episode T: 2 Reward: 15.000
# Total T: 48264 Episode Num: 29591 Episode T: 1 Reward: -7.000
# Total T: 48279 Episode Num: 29601 Episode T: 1 Reward: 1.000
# Total T: 48280 Episode Num: 29601 Episode T: 2 Reward: 13.000
# Total T: 48281 Episode Num: 29601 Episode T: 3 Reward: 26.000
# Total T: 48282 Episode Num: 29601 Episode T: 4 Reward: 50.000
# Total T: 48283 Episode Num: 29601 Episode T: 5 Reward: 85.000
# Total T: 48284 Episode Num: 29601 Episode T: 6 Reward: 131.000
# Total T: 48285 Episode Num: 29601 Episode T: 7 Reward: 188.000
# Total T: 48286 Episode Num: 29601 Episode T: 8 Reward: 256.000
# Total T: 48287 Episode Num: 29601 Episode T: 9 Reward: 325.000
# Total T: 48288 Episode Num: 29601 Episode T: 10 Reward: 397.000
# Total T: 48307 Episode Num: 29611 Episode T: 1 Reward: 1.000
# Total T: 48308 Episode Num: 29611 Episode T: 2 Reward: 3.000
# Total T: 48309 Episode Num: 29611 Episode T: 3 Reward: 6.000
# Total T: 48310 Episode Num: 29611 Episode T: 4 Reward: 10.000
# Total T: 48311 Episode Num: 29611 Episode T: 5 Reward: 17.000
# Total T: 48334 Episode Num: 29621 Episode T: 1 Reward: -7.000
# Total T: 48354 Episode Num: 29631 Episode T: 1 Reward: -7.000
# Total T: 48374 Episode Num: 29641 Episode T: 1 Reward: -7.000
# Total T: 48406 Episode Num: 29651 Episode T: 1 Reward: -7.000
# Total T: 48420 Episode Num: 29661 Episode T: 1 Reward: 11.000
# Total T: 48421 Episode Num: 29661 Episode T: 2 Reward: 15.000
# Total T: 48433 Episode Num: 29671 Episode T: 1 Reward: 3.000
# Total T: 48458 Episode Num: 29681 Episode T: 1 Reward: 3.000
# Total T: 48487 Episode Num: 29691 Episode T: 1 Reward: 11.000
# Total T: 48488 Episode Num: 29691 Episode T: 2 Reward: 15.000
# Total T: 48502 Episode Num: 29701 Episode T: 1 Reward: 1.000
# Total T: 48503 Episode Num: 29701 Episode T: 2 Reward: 5.000
# Total T: 48517 Episode Num: 29711 Episode T: 1 Reward: -7.000
# Total T: 48532 Episode Num: 29721 Episode T: 1 Reward: -7.000
# Total T: 48550 Episode Num: 29731 Episode T: 1 Reward: 3.000
# Total T: 48570 Episode Num: 29741 Episode T: 1 Reward: 1.000
# Total T: 48571 Episode Num: 29741 Episode T: 2 Reward: 5.000
# Total T: 48592 Episode Num: 29751 Episode T: 1 Reward: 1.000
# Total T: 48593 Episode Num: 29751 Episode T: 2 Reward: 3.000
# Total T: 48594 Episode Num: 29751 Episode T: 3 Reward: 16.000
# Total T: 48595 Episode Num: 29751 Episode T: 4 Reward: 30.000
# Total T: 48596 Episode Num: 29751 Episode T: 5 Reward: 55.000
# Total T: 48597 Episode Num: 29751 Episode T: 6 Reward: 73.000
# Total T: 48616 Episode Num: 29761 Episode T: 1 Reward: 1.000
# Total T: 48617 Episode Num: 29761 Episode T: 2 Reward: -5.000
# Total T: 48635 Episode Num: 29771 Episode T: 1 Reward: -7.000
# Total T: 48654 Episode Num: 29781 Episode T: 1 Reward: 3.000
# Total T: 48672 Episode Num: 29791 Episode T: 1 Reward: 11.000
# Total T: 48673 Episode Num: 29791 Episode T: 2 Reward: 23.000
# Total T: 48674 Episode Num: 29791 Episode T: 3 Reward: 38.000
# Total T: 48691 Episode Num: 29801 Episode T: 1 Reward: 3.000
# Total T: 48710 Episode Num: 29811 Episode T: 1 Reward: 1.000
# Total T: 48711 Episode Num: 29811 Episode T: 2 Reward: 5.000
# Total T: 48725 Episode Num: 29821 Episode T: 1 Reward: 11.000
# Total T: 48726 Episode Num: 29821 Episode T: 2 Reward: 23.000
# Total T: 48727 Episode Num: 29821 Episode T: 3 Reward: 28.000
# Total T: 48753 Episode Num: 29831 Episode T: 1 Reward: 3.000
# Total T: 48768 Episode Num: 29841 Episode T: 1 Reward: -7.000
# Total T: 48783 Episode Num: 29851 Episode T: 1 Reward: 1.000
# Total T: 48784 Episode Num: 29851 Episode T: 2 Reward: 5.000
# Total T: 48797 Episode Num: 29861 Episode T: 1 Reward: -7.000
# Total T: 48816 Episode Num: 29871 Episode T: 1 Reward: 3.000
# Total T: 48836 Episode Num: 29881 Episode T: 1 Reward: 1.000
# Total T: 48837 Episode Num: 29881 Episode T: 2 Reward: 3.000
# Total T: 48838 Episode Num: 29881 Episode T: 3 Reward: 6.000
# Total T: 48839 Episode Num: 29881 Episode T: 4 Reward: 12.000
# Total T: 48855 Episode Num: 29891 Episode T: 1 Reward: -7.000
# Total T: 48878 Episode Num: 29901 Episode T: 1 Reward: 11.000
# Total T: 48879 Episode Num: 29901 Episode T: 2 Reward: 15.000
# Total T: 48894 Episode Num: 29911 Episode T: 1 Reward: 1.000
# Total T: 48895 Episode Num: 29911 Episode T: 2 Reward: -5.000
# Total T: 48910 Episode Num: 29921 Episode T: 1 Reward: 1.000
# Total T: 48911 Episode Num: 29921 Episode T: 2 Reward: -5.000
# Total T: 48925 Episode Num: 29931 Episode T: 1 Reward: 11.000
# Total T: 48926 Episode Num: 29931 Episode T: 2 Reward: 15.000
# Total T: 48944 Episode Num: 29941 Episode T: 1 Reward: 3.000
# Total T: 48957 Episode Num: 29951 Episode T: 1 Reward: 11.000
# Total T: 48958 Episode Num: 29951 Episode T: 2 Reward: 15.000
# Total T: 48980 Episode Num: 29961 Episode T: 1 Reward: 11.000
# Total T: 48981 Episode Num: 29961 Episode T: 2 Reward: 25.000
# Total T: 48999 Episode Num: 29971 Episode T: 1 Reward: -7.000
# Total T: 49015 Episode Num: 29981 Episode T: 1 Reward: 11.000
# Total T: 49016 Episode Num: 29981 Episode T: 2 Reward: 23.000
# Total T: 49017 Episode Num: 29981 Episode T: 3 Reward: 46.000
# Total T: 49018 Episode Num: 29981 Episode T: 4 Reward: 62.000
# Total T: 49043 Episode Num: 29991 Episode T: 1 Reward: 3.000
# Total T: 49062 Episode Num: 30001 Episode T: 1 Reward: 1.000
# Total T: 49063 Episode Num: 30001 Episode T: 2 Reward: -5.000
# Total T: 49079 Episode Num: 30011 Episode T: 1 Reward: 11.000
# Total T: 49080 Episode Num: 30011 Episode T: 2 Reward: 23.000
# Total T: 49081 Episode Num: 30011 Episode T: 3 Reward: 46.000
# Total T: 49082 Episode Num: 30011 Episode T: 4 Reward: 62.000
# Total T: 49106 Episode Num: 30021 Episode T: 1 Reward: 11.000
# Total T: 49107 Episode Num: 30021 Episode T: 2 Reward: 25.000
# Total T: 49125 Episode Num: 30031 Episode T: 1 Reward: 1.000
# Total T: 49126 Episode Num: 30031 Episode T: 2 Reward: 3.000
# Total T: 49127 Episode Num: 30031 Episode T: 3 Reward: 8.000
# Total T: 49149 Episode Num: 30041 Episode T: 1 Reward: 1.000
# Total T: 49150 Episode Num: 30041 Episode T: 2 Reward: 5.000
# Total T: 49174 Episode Num: 30051 Episode T: 1 Reward: -7.000
# Total T: 49194 Episode Num: 30061 Episode T: 1 Reward: -7.000
# Total T: 49212 Episode Num: 30071 Episode T: 1 Reward: 1.000
# Total T: 49213 Episode Num: 30071 Episode T: 2 Reward: -5.000
# Total T: 49236 Episode Num: 30081 Episode T: 1 Reward: 11.000
# Total T: 49237 Episode Num: 30081 Episode T: 2 Reward: 15.000
# Total T: 49251 Episode Num: 30091 Episode T: 1 Reward: -7.000
# Total T: 49269 Episode Num: 30101 Episode T: 1 Reward: 1.000
# Total T: 49270 Episode Num: 30101 Episode T: 2 Reward: 3.000
# Total T: 49271 Episode Num: 30101 Episode T: 3 Reward: -2.000
# Total T: 49296 Episode Num: 30111 Episode T: 1 Reward: 3.000
# Total T: 49317 Episode Num: 30121 Episode T: 1 Reward: 11.000
# Total T: 49318 Episode Num: 30121 Episode T: 2 Reward: 33.000
# Total T: 49319 Episode Num: 30121 Episode T: 3 Reward: 66.000
# Total T: 49320 Episode Num: 30121 Episode T: 4 Reward: 100.000
# Total T: 49321 Episode Num: 30121 Episode T: 5 Reward: 127.000
# Total T: 49341 Episode Num: 30131 Episode T: 1 Reward: 3.000
# Total T: 49357 Episode Num: 30141 Episode T: 1 Reward: -7.000
# Total T: 49381 Episode Num: 30151 Episode T: 1 Reward: 3.000
# Total T: 49398 Episode Num: 30161 Episode T: 1 Reward: 11.000
# Total T: 49399 Episode Num: 30161 Episode T: 2 Reward: 15.000
# Total T: 49421 Episode Num: 30171 Episode T: 1 Reward: 3.000
# Total T: 49441 Episode Num: 30181 Episode T: 1 Reward: -7.000
# Total T: 49458 Episode Num: 30191 Episode T: 1 Reward: 3.000
# Total T: 49471 Episode Num: 30201 Episode T: 1 Reward: -7.000
# Total T: 49488 Episode Num: 30211 Episode T: 1 Reward: 1.000
# Total T: 49489 Episode Num: 30211 Episode T: 2 Reward: 13.000
# Total T: 49490 Episode Num: 30211 Episode T: 3 Reward: 28.000
# Total T: 49512 Episode Num: 30221 Episode T: 1 Reward: 1.000
# Total T: 49513 Episode Num: 30221 Episode T: 2 Reward: -5.000
# Total T: 49532 Episode Num: 30231 Episode T: 1 Reward: 11.000
# Total T: 49533 Episode Num: 30231 Episode T: 2 Reward: 25.000
# Total T: 49555 Episode Num: 30241 Episode T: 1 Reward: 11.000
# Total T: 49556 Episode Num: 30241 Episode T: 2 Reward: 23.000
# Total T: 49557 Episode Num: 30241 Episode T: 3 Reward: 38.000
# Total T: 49573 Episode Num: 30251 Episode T: 1 Reward: 3.000
# Total T: 49591 Episode Num: 30261 Episode T: 1 Reward: 1.000
# Total T: 49592 Episode Num: 30261 Episode T: 2 Reward: 5.000
# Total T: 49611 Episode Num: 30271 Episode T: 1 Reward: 1.000
# Total T: 49612 Episode Num: 30271 Episode T: 2 Reward: 13.000
# Total T: 49613 Episode Num: 30271 Episode T: 3 Reward: 28.000
# Total T: 49636 Episode Num: 30281 Episode T: 1 Reward: 11.000
# Total T: 49637 Episode Num: 30281 Episode T: 2 Reward: 23.000
# Total T: 49638 Episode Num: 30281 Episode T: 3 Reward: 46.000
# Total T: 49639 Episode Num: 30281 Episode T: 4 Reward: 62.000
# Total T: 49656 Episode Num: 30291 Episode T: 1 Reward: 3.000
# Total T: 49671 Episode Num: 30301 Episode T: 1 Reward: 1.000
# Total T: 49672 Episode Num: 30301 Episode T: 2 Reward: -5.000
# Total T: 49689 Episode Num: 30311 Episode T: 1 Reward: 1.000
# Total T: 49690 Episode Num: 30311 Episode T: 2 Reward: 3.000
# Total T: 49691 Episode Num: 30311 Episode T: 3 Reward: 16.000
# Total T: 49692 Episode Num: 30311 Episode T: 4 Reward: 30.000
# Total T: 49693 Episode Num: 30311 Episode T: 5 Reward: 47.000
# Total T: 49708 Episode Num: 30321 Episode T: 1 Reward: 11.000
# Total T: 49709 Episode Num: 30321 Episode T: 2 Reward: 15.000
# Total T: 49728 Episode Num: 30331 Episode T: 1 Reward: 1.000
# Total T: 49729 Episode Num: 30331 Episode T: 2 Reward: 5.000
# Total T: 49747 Episode Num: 30341 Episode T: 1 Reward: -7.000
# Total T: 49765 Episode Num: 30351 Episode T: 1 Reward: -7.000
# Total T: 49777 Episode Num: 30361 Episode T: 1 Reward: -7.000
# Total T: 49793 Episode Num: 30371 Episode T: 1 Reward: 1.000
# Total T: 49794 Episode Num: 30371 Episode T: 2 Reward: 3.000
# Total T: 49795 Episode Num: 30371 Episode T: 3 Reward: 8.000
# Total T: 49822 Episode Num: 30381 Episode T: 1 Reward: 11.000
# Total T: 49823 Episode Num: 30381 Episode T: 2 Reward: 25.000
# Total T: 49850 Episode Num: 30391 Episode T: 1 Reward: 3.000
# Total T: 49870 Episode Num: 30401 Episode T: 1 Reward: -7.000
# Total T: 49885 Episode Num: 30411 Episode T: 1 Reward: 1.000
# Total T: 49886 Episode Num: 30411 Episode T: 2 Reward: 13.000
# Total T: 49887 Episode Num: 30411 Episode T: 3 Reward: 26.000
# Total T: 49888 Episode Num: 30411 Episode T: 4 Reward: 40.000
# Total T: 49889 Episode Num: 30411 Episode T: 5 Reward: 65.000
# Total T: 49890 Episode Num: 30411 Episode T: 6 Reward: 101.000
# Total T: 49891 Episode Num: 30411 Episode T: 7 Reward: 138.000
# Total T: 49892 Episode Num: 30411 Episode T: 8 Reward: 168.000
# Total T: 49907 Episode Num: 30421 Episode T: 1 Reward: 1.000
# Total T: 49908 Episode Num: 30421 Episode T: 2 Reward: 3.000
# Total T: 49909 Episode Num: 30421 Episode T: 3 Reward: -2.000
# Total T: 49926 Episode Num: 30431 Episode T: 1 Reward: -7.000
# Total T: 49948 Episode Num: 30441 Episode T: 1 Reward: 11.000
# Total T: 49949 Episode Num: 30441 Episode T: 2 Reward: 15.000
# Total T: 49975 Episode Num: 30451 Episode T: 1 Reward: 3.000

# %%
def evaluate_policy(policy, env, seed=42):
    env_test = env
    state, _ = env_test.reset()
    done = False
    total_reward = 0
    while not done:
        state = torch.FloatTensor(state).unsqueeze(0)
        action = policy.select_action(state)
        next_state, reward, done, _, _ = env_test.step(action)
        state = next_state
        total_reward += reward
    return total_reward

# %%
def reward(self, penalty, action):
    extra = 0
    if self.done == 1 and self.correct_solution == 0:
        extra = -8
    if action == 2:
        penalty = -5
    return self.prob_count * 13 + self.listen_to_feedback_count * 10 + extra + penalty + self.convo_turn + self.progress_delta

env = simulator(reward)

rewards = [evaluate_policy(policy,env) for i in range(10000)]

# %%
import matplotlib.pyplot as plt

rewards_average = []
for i in range(0,10000,100):
    rewards_average.append(np.mean(rewards[i: i+100]))


plt.figure(figsize=(10, 5))
plt.plot(rewards_average)
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Pendulum with TD3')
plt.grid()
plt.show()

# %%
import pickle
dbfile = open('TD3_rewards_average.pkl', 'wb')
pickle.dump(rewards_average, dbfile)
dbfile.close()

# %%
evaluation_td3

import numpy as np
import seaborn as sns

sns.regplot(x=np.arange(len(evaluation_td3)), y=evaluation_td3)
plt.show()

# %%
# reward 
# reward = self.correct_solution * 5 + penalty + (1 + self.done) # TD3 starts to learn something

# %%
plt.figure(figsize=(10, 5))
plt.scatter(np.arange(len(evaluation_td3)), evaluation_td3)
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Pendulum with TD3')
plt.grid()
plt.show()
